# %% [markdown]
# # TWITTER SENTIMENT ANALYSIS

# %% [markdown]
# # dataset information

# %% [markdown]
# The objective of this task is to detect hate speech in tweets. For the sake of simplicity, we say a tweet contains hate speech if it has a racist or sexist sentiment associated with it. So, the task is to classify racist or sexist tweets from other tweets.
#
# Formally, given a training sample of tweets and labels, where label '1' denotes the tweet is racist/sexist and label '0' denotes the tweet is not racist/sexist, your objective is to predict the labels on the test dataset.
#
# Hate  speech  is  an  unfortunately  common  occurrence  on  the  Internet.  Often social media sites like Facebook and Twitter face the problem of identifying and censoring  problematic  posts  while weighing the right to freedom of speech. The  importance  of  detecting  and  moderating hate  speech  is  evident  from  the  strong  connection between hate speech and actual hate crimes. Early identification of users promoting  hate  speech  could  enable  outreach  programs that attempt to prevent an escalation from speech to action. Sites such as Twitter and Facebook have been seeking  to  actively  combat  hate  speech. In spite of these reasons, NLP research on hate speech has been very limited, primarily due to the lack of a general definition of hate speech, an analysis of its demographic influences, and an investigation of the most effective features.

# %% [markdown]
# Evaluation Metric:
# The metric used for evaluating the performance of classification model would be F1-Score.
#
# The metric can be understood as -
#
# True Positives (TP) - These are the correctly predicted positive values which means that the value of actual class is yes and the value of predicted class is also yes.
#
# True Negatives (TN) - These are the correctly predicted negative values which means that the value of actual class is no and value of predicted class is also no.
#
# False Positives (FP) – When actual class is no and predicted class is yes.
#
# False Negatives (FN) – When actual class is yes but predicted class in no.
#
# Precision = TP/TP+FP
#
# Recall = TP/TP+FN
#
# F1 Score = 2*(Recall * Precision) / (Recall + Precision)
#
# F1 is usually more useful than accuracy, especially if for an uneven class distribution.

# %% [markdown]
# # dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:/sentiment anlysis/train_E6oV3lV.csv")
df
# Out:
#           id  label                                              tweet
# 0          1      0   @user when a father is dysfunctional and is s...
# 1          2      0  @user @user thanks for #lyft credit i can't us...
# 2          3      0                                bihday your majesty
# 3          4      0  #model   i love u take with u all the time in ...
# 4          5      0             factsguide: society now    #motivation
# ...      ...    ...                                                ...
# 31957  31958      0  ate @user isz that youuu?ðððððð...
# 31958  31959      0    to see nina turner on the airwaves trying to...
# 31959  31960      0  listening to sad songs on a monday morning otw...
# 31960  31961      1  @user #sikh #temple vandalised in in #calgary,...
# 31961  31962      0                   thank you @user for you follow
#
# [31962 rows x 3 columns]

# %%
x=df.drop('label',axis=1)

# %%
y=df['label']

# %% [markdown]
# # module importing

# %% [markdown]
# Used models:
# *LSTM BI-DIRECTIONAL RNN

# %%
import tensorflow as tf
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.preprocessing.text import one_hot

# %%
voc_size=5000

# %%
messages=x.copy()

# %%
messages
# Out:
#           id                                              tweet
# 0          1   @user when a father is dysfunctional and is s...
# 1          2  @user @user thanks for #lyft credit i can't us...
# 2          3                                bihday your majesty
# 3          4  #model   i love u take with u all the time in ...
# 4          5             factsguide: society now    #motivation
# ...      ...                                                ...
# 31957  31958  ate @user isz that youuu?ðððððð...
# 31958  31959    to see nina turner on the airwaves trying to...
# 31959  31960  listening to sad songs on a monday morning otw...
# 31960  31961  @user #sikh #temple vandalised in in #calgary,...
# 31961  31962                   thank you @user for you follow
#
# [31962 rows x 2 columns]

# %% [markdown]
# # text preprocessing

# %%
import nltk
import re
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\KAUSHIK\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
corpus = []
for i in range(0, len(messages)):
    review = re.sub('[^a-zA-Z]', ' ', str(messages['tweet'][i]))
    review = review.lower()
    review = review.split()
    
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['user father dysfunct selfish drag kid dysfunct run',
#  'user user thank lyft credit use caus offer wheelchair van pdx disapoint getthank',
#  'bihday majesti',
#  'model love u take u time ur',
#  'factsguid societi motiv',
#  'huge fan fare big talk leav chao pay disput get allshowandnogo',
#  'user camp tomorrow user user user user user user user danni',
#  'next school year year exam think school exam hate imagin actorslif revolutionschool girl',
#  'love land allin cav champion cleveland clevelandcavali',
#  'user user welcom gr',
#  'ireland consum price index mom climb previou may blog silver gold forex',
#  'selfish orlando standwithorlando pulseshoot orlandoshoot biggerproblem selfish heabreak valu love',
#  'get see daddi today day gettingf',
#  'user cnn call michigan middl school build wall chant tcot',
#  'comment australia opkillingbay seashepherd helpcovedolphin thecov helpcovedolphin',
#  'ouch junior angri got junior yugyoem omg',
#  'thank paner thank posit',
#  'retweet agre',
#  'friday smile around via ig user user cooki make peopl',
#  'know essenti oil made chemic',
#  'euro peopl blame ha conced goal fat rooney gave away free kick know bale hit',
#  'sad littl dude badday coneofsham cat piss funni laugh',
#  'product day happi man wine tool weekend time open amp drink',
#  'user user lumpi say prove lumpi',
#  'user tgif ff gamedev indiedev indiegamedev squad user user user user user',
#  'beauti sign vendor upsideofflorida shopalyssa love',
#  'user smile media pressconfer antalya turkey sunday throwback love',
#  'great panel mediat public servic ica',
#  'happi father day user',
#  'peopl went nightclub good night man action mean peopl lost famili forev rip orlando',
#  'never chanc vote presidenti candid excit cycl look differ',
#  'alohafriday time exist positivevib hawaiian user user user user',
#  'user rip fellow nohern ireland fan sadley pass away tonight gawa forev sing cheer fire',
#  'hard monday due cloudi weather disabl oxygen product today goodnight badmonday',
#  'unbeliev st centuri need someth like neverump xenophobia',
#  'taylorswift bull domin bull direct whatev want w',
#  'morn travelingram dalat ripinkylif',
#  'user one word tell photoshop enoughisenough dontphotoshopeveryth wheresallthenaturalphoto',
#  'oh cedarpoint wait hour valravn line stop work close',
#  'thank sunshin thank posit',
#  'final finish book work awhil bookworm ontothenextnovel',
#  'yup knick fan hard easier nba fan playoff roll around',
#  'life social network embrac day',
#  'mom share bihday user bihday snake see weekend',
#  'love echeveria bloom flower grow garden iphonesia bliss bloom basilicabotanica',
#  'amaz posit affirm',
#  'model love u take u time ur',
#  'whenev im someth goe wrong',
#  'feel blue illustr',
#  'best pa life know',
#  'abc get readi remov victum frm pulseclub prayfororlando',
#  'bihday got nose job user bihday petunia love',
#  'concelebr albanpilgrimag first time user',
#  'user let scum baggeri begin',
#  'thank super love zpamdelacruz wed dolor capa tarlac',
#  'scourg play baroqu piec piano beyond belief',
#  'user let fight love peac',
#  'happi father day mr rayo video father day rayo world hotvideo video',
#  'user ascot time babe ascot fashion monochrom style instahappyday',
#  'weekend selfi yolo xoxo like like',
#  'happi work confer right mindset lead cultur develop organ work mindset',
#  'christina grimmi last perform shot via user christinarip voic christinagrimmi',
#  'readi danc roar preschool student proud',
#  'realli hu feel',
#  'user wife ador miss poland show surgeri name bridget amp everyth',
#  'user jealou right chatiado',
#  'celebr everi man play fatherli role father day',
#  'sure happi hour',
#  'white establish blk folx run around love promot great',
#  'good morn journey begin travel yeah thejourneybegin hello',
#  'user luv hottweet like venusexchang',
#  'new brochur arriv excit awork solut',
#  'much stuff happen florida first orlando shoot disneygatorattack two year old kid',
#  'user ferrari sake championship gp clearli turn point rb ferrari merc',
#  'ace first test proud',
#  'seek probe udtapunjab leak point finger amarind aap',
#  'user wrap senseaboutmath user th user user user',
#  'user hey white peopl call peopl white user race ident med',
#  'user user might shown today regurgit talk point name call',
#  'sometim rais brow rais bar golfstrengthandcondit strong felixfoisgolf',
#  'greathonour careerconvo user user',
#  'user design innov learn space user includ wateringhol cave mountaintop campfir user h',
#  'altright use amp insecur lure men whitesupremaci',
#  'carri gun help take gun control stop black market terror get wors',
#  'use power mind heal bodi altwaystoh healthi peac',
#  'woohoo week go',
#  'far away place famili member hu',
#  'readi rehears tonight new music new video look announc midweek newmus watchthisspac guitar',
#  'monday night pm channel final get see fuss',
#  'watch new episod user user',
#  'user offlin nice long night snapchat user redhead vermillionr',
#  'thing incred peopl',
#  'ye receiv accept letter master back user octob goodtim histori',
#  'daughter ride bike around driveway son play guitar us enjoy campfir summeim memori',
#  'omg love station way jam work get work done cours memori user',
#  'user alway hope one day get hug think gonna happen anytim soon',
#  'model love u take u time ur',
#  'coupl sex fat nake japanes girl',
#  'hump hump day humper edwardsvil pennsylvania',
#  'personalis gbp get shop cool home fun',
#  'truli sick ppl',
#  'trump call obama resign orlando shoot boy point year talk chang',
#  'user user user user long nashvilletour nashvilleforev',
#  'eur usd clear barrier jump fresh week high blog silver gold forex',
#  'go la tomorrow',
#  'thank good friend thank posit',
#  'still wrap head around fact christinagrimmi gone fact man destroy prayfororlando',
#  'receiv di user wait sta bake eyelid',
#  'play vigilfororlando harp clonakilti rip via user',
#  'user ye ye ye ihavenofriend someonecomewithm',
#  'sunday weekend relax icon woman sundaymorn sunday marilynmonro',
#  'user interest linguist address race amp racism power raciolinguist bring',
#  'one belov long lost cd recov thank appl music',
#  'marvel song musica weed ripchristina adel danc vine user',
#  'user user mock obama black user user user user brexit',
#  'spell brexit referendum commerzbank blog silver gold forex',
#  'amaz health benefit cucumb healthi altwaystoh',
#  'model love u take u time ur',
#  'work ofw pinoy followm iger instagood smile love',
#  'toradora anim animeedit made breakup alon lone',
#  'lap pool k ride done pick gym membership form',
#  'cotd polar bear climb race angri polar bear climb race polar bear live cold place look',
#  'user user get angri muslim assassin much',
#  'happi snappi wait footbal footbal snapchat',
#  'friday miss fring qcbag summer',
#  'nochebuena lasvega usa la vega strip',
#  'fleurett instaboy instaman sefi septum friend smile blackandwhit',
#  'sad branch raini day write tear fli bird haiku line micropoetri',
#  'yeah new button mail pretti jewelrymak button',
#  'user driver hit femal moos river rd weston moos kill driver ok crew remov anim',
#  'afterpa made japan madeinjapan eo cute fun cawaii love strawberri tomato',
#  'peopl protest trump republican trump fuher amp',
#  'need find way spend time alway mind boy guy',
#  'updat social analyt photooftheday iger like',
#  'anyon know date doj fbi becam corrupt emailg hillari shame disgrac ridicul',
#  'stupid make even neglig put sachintendulkar instal u go take',
#  'bihday thbihday bestfriend love',
#  'user impoant thing enjoy life matter life sho pooh u',
#  'happi bihday chri evan great actor human chrisevan bihday',
#  'hea thought prayer go peopl murder gay nightclub florida',
#  'user demo guitar new album newalbum indi guitar echobelli',
#  'retweet lion pro user tgif webmaret seo commun manag weekend',
#  'nzd usd target week sma blog silver gold forex',
#  'user pretti bad bihday week far worst ever bihdayweeksuck bithday',
#  'bless work sa best lead ladi',
#  'happiest place eah disneysmagickingdom disney magickingdom disneyland orlando',
#  'kinda among human',
#  'found user user exclaim user gr blain hair nite',
#  'user lt listen beauti best friend user sing amaz voic lt lt lt lt',
#  'n healthi freedom effo present mere mean effo store past theodor roosevelt',
#  'know yall aint go know love commit trust faith',
#  'ye call michelleobama gorilla racist long thought black peopl bet',
#  'newarkfestiv us year wait show sta rd year run',
#  'internet broken watch netflix mochithepug puglif',
#  'user user user busi usual',
#  'hbd dick suckin tequila lovin slut wouldnt want u way justalil butstillontim',
#  'smaller hand show barri probabl lie knick game suck golf',
#  'good morn friday everyon weekend goodmorn friday girl love florida',
#  'challeng aap claim punjabi drugaddict dare prove',
#  'tracerequest send deepest condol orlando gay famili zimbabw gay commun hea touch',
#  'new selfi guy mato chapon',
#  'saturday afternoon chi meet friend user user user',
#  'model love u take u time ur',
#  'so nut amp bolt bloke',
#  'aww yeah good bing bong bing bong',
#  'dawn month see user live excit vfest summer',
#  'user happi th bihday shane robe watson bihday shane watson australia cricker',
#  'user user point one finger user million point right back jewishsupremacist',
#  'sad hear announc say may move player one two lead whoknow',
#  'radio go coldplay tonight oh ye',
#  'u think like god come god keep',
#  'user terrorist constitut right anoth excus republican appeas nra gun control measur',
#  'user user gloucesterrugbi',
#  'user sad user happen',
#  'everyon everyth sad togeth alon fine dandi lone exuber depress halfful halfempti',
#  'mikeashley sposdirectsham perhaps good exampl need protect workersright within europ euref remain',
#  'angri bird stella bad princess bird stella bad princess birdsstellabadprincess time post wed',
#  'check user incred made great memori great peopl',
#  'saw shi last night said rip care realli',
#  'user hilari user alreadi block user ask one paicularli difficult question user',
#  'devast news hea goe victim famili orlando heabreak',
#  'happi state arriv manner travel margaret lee runbeck happi quot inspir',
#  'safe way heal acn altwaystoh healthi heal',
#  'creat right beat makingbeat thursday work istandard akaipro',
#  'wed number wed weddingpay love forev weddingdress',
#  'look forward attend cipd ireland confer amp workshop cpd onemoreday user user',
#  'final reach follow twitch follow hypu stream tomorrow',
#  'word r free u use em cost verbal abus hu love adult teen user',
#  'countri went last year see peopl bring bomb stadium amp come everyth footbal',
#  'thank cat thank posit',
#  'time eat bae swalscha dejeun lunch happi love amoureux',
#  'ilovethesecret lawofattract quiz love happi motiv success joy life',
#  'might libtard libtard sjw liber polit',
#  'go pole bgp rozthediva blackgirlspol bodyandpol live love',
#  'argentina attack bull game realli think head empti around citi side',
#  'self serv hypocrit alway keep eye bounc ball nimrod presid',
#  'nohcarolina bull domin bull direct whatev want whe',
#  'build polar bear climb race angri polar bear climb race polar bear live cold place loo',
#  'user user want reelect money ksleg',
#  'hea orlando right truli cannot imagin could easili happen anywher',
#  'alreemgroup ali alshahawi ad cute summer photographerdubai sun hair mydubai',
#  'seem like place action montreal',
#  'user old wash',
#  'spirit posit affirm',
#  'thank enteain thank posit',
#  'user user user show truli bad brisban',
#  'user wait wimbledon',
#  'happi man success model entrepreneur speaker ff fresh confid fashion',
#  'gala moment day kid bipolar frikiegirl lucki chinatown mall binondo',
#  'realli take piss angri goe show valu complet utter moron',
#  'user take trash america vote hate vote vote vot',
#  'father day amaz dad give much famili enjoy',
#  'magnettherapi realli work altwaystoh heal healthi',
#  'sebbo said user',
#  'eg smile smile egsmil torio',
#  'user brilliant servic ketter branch today custom',
#  'user screen miss sing song potp shock treatment',
#  'way toraya bu alamindah white music carrieunderwood',
#  'model love u take u time ur',
#  'good day new beer bridpo food amp beer fest back campsit drunk user starstruck amp move user',
#  'g l repost user propey ocean summer life famili sydney',
#  'want teach love like never felt quot quot love pakistan allin girl boy fashion feel',
#  'thank thank posit',
#  'omg day left countdown nolefam user wait come milan',
#  'user stone rose done time user club day',
#  'reason two peopl stay togeth give someth nobodi els hopelli great day',
#  'never know might crush wakow buzz moment ride love crush date hookup app',
#  'friend got engag',
#  'day lef b end classez yay risay risaypl',
#  'thursday may watch say need said',
#  'legendari posit affirm',
#  'unit state america rest world think proven right firearm',
#  'hold open door woman woman nice thing even tri deni',
#  'good weekend show thank bless jeffreycwilliam',
#  'good hea help everyon alway seem one get hu buttru',
#  'happiest babi ive ever known cute smile babygirl beauti niec bless xo',
#  'readi b c oneteamlincoln user user user user',
#  'wait carowind readi see user user time rockthepark timetogetmyjesuson',
#  'alreadi bought find dori ticket',
#  'everi minut lose sixti second happi',
#  'sanjapan animeconvent see guy septemb',
#  'question day excit moto tech announc moto question',
#  'make today count mondaymotiv livelifetothefullest healthi everydaycount',
#  'happi morn degre anna classmat friend',
#  'user would u abl suppo event brentwood homesta lost fund may close',
#  'happi littl peopl happyhappi peopl kitten cat blackkitten',
#  'user user user thank much oppoun cherish forev',
#  'themeowood puppi',
#  'day till',
#  'happi pharrel william pharrellwilliam lyric',
#  'user happi w ork confer right mindset lead cultur develop organ work',
#  'lost anoth member famili yesterday gut rosi',
#  'yayyy trailer morrow fever super user user user',
#  'watch fanci tail vine mad mad teeth bite piss dog bite dogbit dogtreat',
#  'dreamcatch bull domin bull direct whatev want',
#  'readi tomorrow englishteach teacher ecuador',
#  'memori wonder dad alway miss etern love strong greatquot',
#  'user user dalla shoot video see disturb viewer discret play loop ove',
#  'itako alon fine littl',
#  'sunshin amp sticker kind saturday letthembelittl childhoodunplug',
#  'wonder day today calm sunni chubbygirl glass finnishgirl finn',
#  'buka bersama tma famili yuhuuuuu tma w risha meylucki amp other mayfair townhous pic',
#  'love know nationalbestfriendsday true',
#  'user man ran governor ny state biggest african american popul',
#  'stereotyp prejudic offer hope solut creat old repetit hate conflict',
#  'get pussi quicker day',
#  'probabl time user come back home ugh',
#  'model love u take u time ur',
#  'user anyon play voez kinda love game game game girlgam voez',
#  'mani pol pass mani time said noth bluelivesmatt draintheswamp ferguson',
#  'sequoia weekend',
#  'bitch care eyebrow much makin end week',
#  'bham pride paradereadi beyou ofbham user user user',
#  'fathersday guy play dad love',
#  'bihday bogummi love forev hope happi everyday good night user',
#  'wish client babi goat cuddl',
#  'positivevib fresh love guy get concord mill mall',
#  'conjur get readi scare tonight readyornot truestori',
#  'today day make chang elimin neg choos live posit lifestyl instead',
#  'user aaahh nabilah look arigat jkt happi daaay iwearbanana',
#  'last day work tomorrow self employ monday scare redditchbizhour',
#  'user im half boy half man im dumb',
#  'happi littl boy smile corbinrayp',
#  'never appropri zero idea feel right scare missyou whatwasthat',
#  'user magnific monday mondaymorn mondaymotiv monday indraloka',
#  'dont understand design print anim fabric bought user muzlin b sanasafinaz noexchangepolici',
#  'mayb happi hour get end',
#  'littlebear friend joy toddlerfriend puresweet latergram toddlerfun',
#  'never lost love one senseless violenc get fuck opinion nd amend',
#  'world head could lose life leav home orlando',
#  'heard say tri lock shooter kept patron get',
#  'good mood flight user munich user interview pharrel',
#  'first present user netherland user',
#  'u made us proud hv read ur word amp assur b assoment petit emot wish u best',
#  'happi vs joy happi temporari leav u hu joy last forev never leav real tru',
#  'twinklatinboy na slut snapshot hot nasti naughti sexi horni shi porn nude kinki xxx',
#  'user peopl thank thank peopl happi thankfulthursday',
#  'creativ posit affirm',
#  'held back tear cri happi tear amp final leav week tomorrow user user canadianrav',
#  'bihday pressi mummi granni michaelkor luckygirl bihday liverpool',
#  'user stuck athen instead santorini user said windi land shock servic everi level sinc',
#  'user happi folk first freakshak launch freak yum dalston user',
#  'huge crowd trump',
#  'thank saturday thank posit',
#  'good god',
#  'user enjoy delici melon vegan organ fresh fruit organ healthi healthyliv life',
#  'first month week day till begin end user sad time',
#  'firework weeheeee',
#  'blackpool attack bull game realli think head empti around citi side',
#  'fathersday amaz father today',
#  'want much ask',
#  'user readi wait newblood',
#  'sad aunt pass away funer',
#  'horribl ad made us cring',
#  'mind robson kanu decent player avail free transfer',
#  'user come user better pleas put user shoe unnecessari stress h',
#  'stalk watch peon poor disabl kill usa usa use b proud amp univers care',
#  'stephcurri outburst beg question christian get nbafin',
#  'grate affirm',
#  'week go im san antonio bound see user cant wait see littl brother missyou mybrotherskeep',
#  'listen gt gt gt gt gt gt gt',
#  'user die light villag green town antisemit hocoschool columbiamd hocomd',
#  'hahaha last friday amp weird',
#  'hey notic u train lover ask u check free app known train appl',
#  'sexi fuck direction niall nialhoranfact niallerwin hot justindrewbieb justindb believet',
#  'user father sday say love dad right sanya whererefreshingbegin',
#  'guess back back lifeaftersurgeri dog dogslif labrador labradorretriev lifeofsam',
#  'hey superspoilt may want check latest updat glastofest',
#  'user user user user user bihday sid god bless hav success career',
#  'nba final ambival love steph thompson kyri stink green class doosh lebron talk guillermo',
#  'check product team web seri episod edit truli mep webseri',
#  'model love u take u time ur',
#  'user never answer statement nazi hatr amp bigotri found w',
#  'juneteenth independenceday food thought rich ancestr heritag independ hall',
#  'river gorilla simul need adapt environ need tear citi materi',
#  'watch user leadership embrac amp kiss donald ass pathet amp user pay pay racism amp hate ripgop',
#  'love matur age',
#  'aww yeah good bing bong bing bong',
#  'user good feel happen smile instalik instamood instap',
#  'check graffiti dublin ireland music vimeo movi video europ peopl flow fun rafalwojcicki',
#  'oitnbseason day aaahhhhh',
#  'user user iamposs today extraordinaryladyspeak staraward user user ht',
#  'sun happi thursday breakfast sun day sunnyday sun blue',
#  'pack sneak peek work yellowjacket neshl user bhl hockey',
#  'toni sunday tonyaward',
#  'happi father day dad dad father day',
#  'user theverdict idiot countri rock bluegrass beatl love pop romanc',
#  'project week june blog silver gold forex',
#  'user dayshappi user dayseventyseven day happi love lifequot life',
#  'littl brother higher toler alcohol lol',
#  'wish guy bihday blaze say user spit imag',
#  'thank hike trail thank posit',
#  'pay meet tackl movi uncov problem want world know',
#  'user chill relax piano music keep pet quiet juli th firework',
#  'might libtard libtard sjw liber polit',
#  'user noth say merica like user tweet',
#  'alway paratyphoid',
#  'user today lost thevoic sister senselessli sing love death peopl stoptheh ripchristina',
#  'guy concern twitter brand honest follow',
#  'hate like famili realli born big ass toxic bomb mother fucker give fuck cuz got money',
#  'get get get enjoy music today free app free music',
#  'best lawofattract resourc heal altwaystoh healthi idwp',
#  'trump ny co chair make racist remark michel obama p p fyi tcot',
#  'user fan make',
#  'music therapi tool heal altwaystoh healthi',
#  'food make famili fight mxm',
#  'delici sangria salud cheer smile pub pembrok',
#  'fabul weekend beauti soul nofilt',
#  'feel overwhelm look see million reason happi love craig',
#  'back day job shane lowri',
#  'hour right bottl amp drink pm user w chippewa st buffalo',
#  'ana nimra farishta mawia khushal number mark obtain damn high p',
#  'monday empti without bachelorett thebachelorett empti nowin',
#  'suppo famili god chivalri tradit pride one heritag controversi',
#  'user pic say otherwis young girl confin kitchen void mean beyond cheap public topoli',
#  'good night faith ever vaitacacommafiasdv',
#  'love simpli love love success work busi',
#  'lunchtim mom torrington lunch afterschool instadaili yummi withmom user',
#  'user sister even know watch argu nigga wait say wrong shit',
#  'ride ride back done cycl sunset ride bike fit cardio dese',
#  'well gonna go see adtr bae',
#  'user tagsforlik food friend summer swag quot love god girl weekend polaroid followm teen win job',
#  'payintheusa polar bear climb race angri polar bear climb race polar bear live cold place',
#  'healthi fam',
#  'dream palac move alreadi stellar girl dreami goodmorn day',
#  'im wait follow sinc x factor',
#  'user fault use pointscor',
#  'user week sta kinda lame get better yay wednesdaywisdom',
#  'user forev user young man luk hot wen temper b alwi ur fan till lst breath h',
#  'worri bee',
#  'doubl tap follow beauti smooth lifestyl skin instas f f fashion',
#  'lawofattract heal loa healthi well idwp',
#  'oil turn flat eye eia inventori data fuher direct blog silver gold forex',
#  'train new employe fun newblood',
#  'first bihday puppi elois sweetbabin dog growingup cute bihdaygirl user',
#  'user pig burn aliv saskatchewan barn fire video',
#  'user never convinc american right bear prayfororlando guncontrol',
#  'beauti ladi bless know smile lovethem',
#  'today baba siddiqu ifftar pay mumbai user amp user dono ayeng see',
#  'hand ombr blue',
#  'user wait go see warcraft ugh warcraft',
#  'cousin reunit famili fun user well',
#  'user audienc duan henri insight',
#  'train move bing tweet',
#  'lover stop angri visit us gt gt gt lover friend astrolog love',
#  'user block troll promis blacklivesmatt amp let nonsens rant boo',
#  'father day dad one heaven',
#  'sdl user june user',
#  'creepi awesom baboon climb fire escap like human user summev zoo',
#  'use power mind heal bodi altwaystoh healthi',
#  'dude tiger roar tiger annaswelshzoo bihdaycelebr',
#  'user laugh happi laugh william jame xtra',
#  'happi sunday everyon think today go good day positivevib sunshin sunday',
#  'talk way organ dehuman us never held account',
#  'stuck rat race find freedom masterkeyexperi',
#  'studi face pizza stole roommat idea take pic',
#  'dinner sister sisteradventur sister ilovemysist',
#  'els plan watch user tomorrow',
#  'usn rifl day snow ar closest ever got user user user navi',
#  'euro bbc pundit make predict franc euro sta today',
#  'user happi happi minion',
#  'elder scroll mani year wah wah bethesda e e',
#  'user poor tiggi littl bit cheeki jax amp soa throwbackthursday user user user',
#  'cannot wait eurogam year pump eurogam',
#  'work russel beckwith soon staytun friend lyle tapfoag',
#  'nazi studi american race law inspir ushistori eugen',
#  'share ice cream sun love outdoor picnic summer famili daughter father dess icecream',
#  'noth like river island sale shop spree cheer retailtherapi riverisland shoppingqueen alwayscheersyouup',
#  'clean ze hous zo ziy laundri final free fever cold happi clean laundryday',
#  'new list ebay woohoo sell sell buy shop shop',
#  'thank challeng thank posit',
#  'chill night ice cream amp grown chill',
#  'user biher absolut origin hate bigotri altright hatr african american potu theresist',
#  'user sweet instagood idola idol followm selfi',
#  'tragedi america first kill christinagrimmi orlando america safe place today',
#  'brexit angst factor help drive interest rate germani japan bbh blog silver gold',
#  'fab amp interest day eacbpm dash quiet place dial iiba emea region meet busi',
#  'kayak sup snorkel swim whatev pleasur put togeth alohabeachbu hawaii explor',
#  'u hold man year watch chang u hear say loyalti',
#  'back go tacloban see ya later great travel tacloban citi catbalogan',
#  'user feel olymp medal',
#  'angri bird il film download ita p hdtc bird download film il ita',
#  'sunday photo user model urbex topless tit mono retweet sexi heel ace',
#  'fo woh offic viral arrest video rude racist chief crime offic',
#  'user user user user saturday friend',
#  'yayyyi friend got marri today congratul guy shegotmarri',
#  'model love u take u time ur',
#  'lewi remain perfect ranger announc gonna stroke',
#  'chri back soccer miss spring season broken',
#  'train ticket book opera week wale',
#  'beauti day sun fun beachpark beach park',
#  'big screen fit right euro',
#  'love stori happi end anim love stori end like like',
#  'poet bull domin bull direct whatev want sta',
#  'tranquil posit affirm',
#  'user name upcom new track pm kpop',
#  'best essentialoil anxieti healthi peac altwaystoh',
#  'user user user wow peopl children noth better insult peopl twitter',
#  'think mayb bought user instead user gettingold becomingbor notborderland goblizzard',
#  'fact user album hour away drip lose mind fatkidinacandystor',
#  'ryderrideu see c c cum togeth snapshot young shi kinki wet porn hot xxx horni',
#  'snapchat gabi china love girl snapchat flower instasmil instalov',
#  'brilliant posit affirm',
#  'user true nigga dont go look apament go look shoe jewelri',
#  'safe way heal acn altwaystoh healthi heal',
#  'msgapparelstoday user u r special us father day',
#  'camp next weekend lovecamp brownwood',
#  'grate affirm',
#  'forev besti karaok friend friendship love nofilt instacool instagood',
#  'user absolut love place fantast welcom carlo receptionist th time room request grant usual',
#  'head thealter peculiar famili',
#  'us retail sale control group like rose may dansk bank blog silver gold forex',
#  'happi father day love life amp best father world user fathersday love',
#  'coolestlifehack world smallest snake motiv',
#  'shockingli increasingli violent world live uk gun control law feel mp famili amp friend',
#  'funni simpli truestori',
#  'happi bihday brithday day holiday monday menmodel',
#  'sadden one thought groom posit ask opinion issu',
#  'ukrainian athlet grosseto user watch livestream without see',
#  'new season oitnb sta tonight oitnbseason',
#  'user excit side cuain tonight look forward see user broadway',
#  'quay collab user say sold noooo whyyyy loveyoudesi',
#  'final get jordan get paid wear lowtop',
#  'impress posit affirm',
#  'father day father make happen salut',
#  'view th floor nyc newyorkc myview girl wine fridaynight',
#  'discuss republican thing critiqu ignor consequ',
#  'got school tomorrow last integr',
#  'amen truth alway lt lt love bless',
#  'user stamford kid got month rape boredom minut action',
#  'let color life w rainbow danian love colour rainbow depok',
#  'aiel aielmaharashtra rude custom care execut make want switch loyalti anoth provid irrit',
#  'hi teddi corpuz rocksteddi band enjoy idol omg',
#  'user wow great daughter send father right father day cheapshot lowblow shame',
#  'reason happi kid mid tantrum parent tantrum toddler calm mind strong',
#  'truth posit affirm',
#  'yup siri maco wwdc woot next work listen skill',
#  'diy done dresser nicknack newelectricscrewdriv brock london',
#  'black amp feel like stomp retweet tampa miami',
#  'user user that problem one polic offic need bigger gun perhap one tank soldier',
#  'father day friend',
#  'choic fall alway write candid',
#  'user end',
#  'get know team behind app keep tummi june issu user bazaarmag',
#  'actual go fish today somewher nice',
#  'cute look like doll',
#  'user im',
#  'love vacat enjoy greec crete sabinedrift chillinn blondegirl bluedress',
#  'user unreal advisor refus take payment say wait pcn custom servic ur site wasnt work',
#  'user gamereadi forza horizon pc time live',
#  'user life better tahiti summer life school tahiti like',
#  'know male thought vagina like video game xd stupidthought quot lmao',
#  'pa pack taken brainwash cheetah downasquadmemb treeout',
#  'japan domest corpor good price index yoy line expect may blog silver',
#  'rememb day peopl bbuk went becom realiti tv star seem realiti tv star becom big brother contest',
#  'user allahsoil familiar becom difficult stereotyp',
#  'user good morn want live life tie goal peopl thing',
#  'user friday lt fridayfeel relax user bristol',
#  'day porn movi pussi pay pic',
#  'look easi till turn rap hiphop rock funni comedi pop kanyewest',
#  'banner merri christma new year freepik ad decor newyear',
#  'user user yay thank let know pa happi man',
#  'exam room test tire annoy',
#  'best homeopath remedi anxieti altwaystoh heal peac',
#  'rest peac christina',
#  'bama fool around might rais child ppl dont think far advanc see fun whatev',
#  'anti racist codeword antiwhit asia asian africa african white countri everyon',
#  'user periscop first god babi graduat high school collegebound',
#  'nearli folk nervou curiou finalis stuff pointer grainn bringiton',
#  'fellowship lifegroup',
#  'caught eat chocol slice bread besid ref realiz still eat dinner',
#  'user prais cleveland polic rnc polic consent decre white tamirric rip',
#  'best lawofattract resourc heal altwaystoh healthi idwp',
#  'everyth need surfday fathersday dad novyspo novytowel surfgear',
#  'user agre',
#  'user next show monday fiddler elbow camden look like go huge night ht',
#  'user swim sign everywher parent watch year old',
#  'mitchellrattl mitchel goodson',
#  'user get readi saturday jeep run nbjc day showyourjeepday jeepmafia jeeplif jeep htt',
#  'user attempt czech furi croatia score second',
#  'latest dairi k thank user user user',
#  'user yep grate everyday gratitud laurasworld',
#  'ebook awhil nice hard copi',
#  'nba final game could basketbal fan ask nbafin',
#  'user prevent bigot',
#  'dear uot despit attempt savechar regret announc lost tragic rip angel friend miss u',
#  'space place color blue fabricsourc finish pillow cushion use us',
#  'perfect moment day',
#  'wait user hour come autograph final walk away come cours disappoint',
#  'fathersday gift dad secur financi futur save insur invest',
#  'girl world sexi matur housewif',
#  'time get happi saturday saturday weekend',
#  'awesom dad almighti father lord darl dad rip sweethea husband babi daddi st son fathersday',
#  'owen footbal tornament footbal',
#  'come ee piss poor recept today month struggl get signal buxton put mast switch grumpi',
#  'excit na',
#  'user let troopingthecolour begin bihdayyourmajesti thequeenat ht',
#  'work fusiona wolv last stage develop chase user user',
#  'user like blacklivesmatt slogan talk',
#  'r p littl bear bear hamster rip imissy',
#  'give hug love cat moment',
#  'lip like fire blood like gasolin love boyfriend smile',
#  'go let peopl icr',
#  'life race allow present user fun',
#  'dental testimoni lichfield client',
#  'thank soo much pretti user feel soo bless amp lucki plz keep shower ur lyk surpris like unexpect',
#  'user user user nice c susanna smile day need fals promis fli dragon got ben',
#  'user back yet',
#  'got call yesterday mom diagnos stage ovarian cancer terrifi terrifi know',
#  'user feminismiscanc feminismisterror feminismmuktbharat malevot ignor user',
#  'user user user side histori alli issu embarrass',
#  'fox new come say bluntli one thing read',
#  'good morn internationaldayofyoga yogalov yoga relax healthi posit',
#  'user monkey also declar vermin protest bajrang dal user user',
#  'user new plant user readi garden garden know',
#  'user coldplay last night fave coldplay conc hampden fave coupl cute',
#  'use power mind heal bodi altwaystoh healthi peac',
#  'flagday mine gorgeou texa sky householdnam takingov',
#  'aww yeah good bing bong bing bong',
#  'user ye let suppo openli prowar anti islam homophob rapist advoc hypocrit',
#  'cat furri persiancat pixion wallpap imag',
#  'good moooooorn tgif kiss kiss friday fridayfun',
#  'user enjoy everyth alreadi given rather alway need bless thank',
#  'euro match schedul design franc vs romania feedback appreci',
#  'father day take dad user love',
#  'berlin thank much user incred theriveourberlin theboss',
#  'listen incubu never hu nowplay sick littl world nissan live set de user',
#  'user anderson cooper amp lemon like gay thrown build sharia ndamend',
#  'bei field dog walk dog',
#  'would steal awork user boohiss',
#  'compet list today whenrealtorscompeteyouwin callm gotheextramil',
#  'user great park total disorganis one poaventura whatajok',
#  'got news berni win dc even vote held last month dcvote',
#  'eur usd print new monthli top draghi eye blog silver gold forex',
#  'two presidenti candid everybodi devolv elect america smh usa',
#  'poor pup anim puppi vine magic subscrib youtub vine user',
#  'rare pic superstar user user bihday sivakoratala',
#  'user user move outsid downtown gr mi neither offer better mbp',
#  'user wish dad happi father day dad fathersday intellicr',
#  'met girl yr ago onlin b ng gay friend look like b user',
#  'face say pwcproud',
#  'b u love instagood user tbt cute beauti followm',
#  'enjoy weekend famili home happi weekend dear friend weekend famili home',
#  'anoth senseless tragedi tragic puls orlandostaystrong thoughtsandpray',
#  'user love yrkkh frm bottom hea frm day stare amp v get return uglyspat user user',
#  'captain felix rutland water littl boat behind go grand adventur',
#  'bing watch seri thekil complet avoid footbal',
#  'quot jeremi corbyn fuck go',
#  'happi travel time instamood moment love mylif russian girl model like',
#  'porn vid wwwsmallgirlsexcom',
#  'user tuesday jacki quot taketim make soul enjoylif smile believ dream havefun',
#  'home sweet home call edinburgh sinc move year ago scotland homesweethom famili',
#  'play england vs russia marseil expect high risk game plenti time drink',
#  'aww yeah good bing bong bing bong',
#  'thank sweater weather thank posit',
#  'haunt atmospher studiotim',
#  'user user becom fan give right critic person life idol',
#  'latest obsidian radio daili thank user user user latesnew',
#  'mind blown learn much googl form workshop user cfisdrrr',
#  'user sexi prettypussi sexybbw realmvp',
#  'user back user v traumat month damag bad thought proof plan work onward amp upward excit',
#  'might libtard libtard sjw liber polit',
#  'overwhelm evid compani trump keep echo sentiment amp ideal dumptrump',
#  'user femal beef commun dick ass nigga',
#  'peopl like alreadi forgot nah new name made hashtag weekli basi',
#  'answer',
#  'cherri color symbol warm posit energi necklac price a stone gift amaz beauti',
#  'wait season begin lfc ynwa englishpremierleagu',
#  'user happi father day dad except rogergoodel fathersday goodellsuck',
#  'orb independ brexit poll show leav vote ahead gbp usd slump blog silver gold forex',
#  'user user user mm mm washout flood good take set anoth day golf',
#  'user ya ever sinc zayn left never',
#  'happi father day lovey fathersday sunday father daddi day',
#  'big shock monday need find new home yeah found dream cottag tuesday',
#  'save thousand free search x login x broker actor seeklearn stafresh',
#  'actual order kyli lip kit',
#  'hope famili made arrang make sure bastard user get access',
#  'socialmedia us firm build nuclear reactor india',
#  'smaphon bull domin bull direct whatev want',
#  'lifeisbeauti loveit workhard trainhard matter go bless fitlif',
#  'oscar tabarez talk lui suarez angri reaction spo lui oscar',
#  'play njoyhit hitmusicst us uk eur user join us nice nyc user',
#  'user week go personaltrain full time new slot avail june pl spread',
#  'mother take care ten children sometim ten children cant take care mother',
#  'thank good night sleep thank posit',
#  'play bride nocturn melancholi melancholymus',
#  'tvk fathersday father day tatay daddi enjoy wath tha voic kid',
#  'thank friend thank posit',
#  'thank mason jar thank posit',
#  'nigger lifelesson white kid grew blogpost whitepeopl respect',
#  'user user user congrat user',
#  'via jt user love sinkthepink music instagay celebspot',
#  'user readi user ccmf mychurch frontrow upshow',
#  'utterli peopl incur stupid africa albino kill malawi spark educ campaign',
#  'gold high back around blog silver gold forex',
#  'shock event orlando usa review gun law innoc die first horrif unforgiv',
#  'knowledg posit affirm',
#  'le sister instatravel instamo igdaili instagramhub instagood instalik',
#  'feel lone',
#  'girliguessimwithh tag saddest represent peopl feel forc vote',
#  'h factor mobil app make user want factor click download aric whitepap',
#  'user meanwhil googl violat free speech',
#  'happi work confer right mindset lead cultur develop organ work mindset',
#  'user rochest attack bull chase leav lot despit fact strong sourc f',
#  'user competit',
#  'tattoosleev gorilla simul need adapt environ need tear citi',
#  'ima go cri hour brb',
#  'tell sorrow river river taught flow without complain sepatu dahlan philosophi proverb',
#  'thank memori thank posit',
#  'user sure nasti piec work lmao',
#  'today perfect day happi lifecoach reinventimposs',
#  'sex sex nake women',
#  'thank cocktail thank posit',
#  'dont wait outsid thepeel work homophob taxi driver guy kiss gay melbourn cab',
#  'user guess one want let resid spring street know abl leav hour today',
#  'great morn deborah user smile kind day',
#  'window split screen browser customcasetab noedit',
#  'user peopl use tragedi like fuel hate agenda toward entir group peopl opposit help',
#  'taeyeon unni fire btw realli hope album cover yellow lol',
#  'john mica hell peopl like elect user user totalpolitician outoftouch disgrac',
#  'noth make dad happier tasti meal fathersday',
#  'truth suicid rate young blackboy',
#  'happi sunday homesweethom amaz love istanbul girl beauti instalik',
#  'oh block least love island look forward sunday',
#  'play suzann ciani clock morn music song',
#  'swing swing mybabygirl babi littlegirl park love cute',
#  'help bubbl attack winter bathtim cozi',
#  'move posit affirm',
#  'thing matter mani law regul gun peopl still find way get hand',
#  'user sunflow natur garden photograpi qualiti print amp card',
#  'user didnt stay long emerg home daughter well soo rush home miss ur set',
#  'user great insight trust profess emea growth hack confer growthwithhubspot',
#  'carolyn cooper ugli poor ignor black',
#  'franklin dog sunshin dogsoftwitt',
#  'perfect day buy real furnitur hike user dinner user dess sleepnumb bonustolongrest dnd',
#  'happi face love smile user satisfi hair workit smile face',
#  'love sunday weekend selfi longhair girl selfporait love',
#  'natur perfect bull hill climb reach target complet task surviv str',
#  'model love u take u time ur',
#  'orlando gay men angri amp donat blood massacr',
#  'user golinglob golinuntern fresh air trail run soul keep golinuntern life balanc',
#  'user user monro amp nick best friend amp rosale amp addi kelli amp babymonrosal grimm famili nadalind',
#  'user lie hillari would call secur inquiri liber like mind one eat shit eat shit',
#  'know find incred disrespect take person call meet frustrat',
#  'date night friday pub ilovehim instagay beer billi burnet',
#  'wish user would make phone damn screen shatter cost arm leg still gotta pay fix em',
#  'hea wrench would state mother know son die',
#  'user time fli less week go brilliant user lead summer confer',
#  'fruit time fruit dess instamo photooftheday yvr sweet vancitybuzz',
#  'sad one gt gt gt',
#  'sirf ashiq log follow karen iqbal galib wasi faraz mohsin ki full poetri add follow user',
#  'user minut go armaanamaalontkss user user user',
#  'thank god royal without kansa citi right cleveland disgrac',
#  'get see favorit person tmrrw',
#  'latina buffalo simul buffalo take vicin home way',
#  'world live orlando',
#  'user vacat begun triathlet triathlon coach vacat fearless rul htt',
#  'user bit heabreak reflect',
#  'user peac way sta morn daili chao begin gratitud',
#  'hardcor girl video birday sex xxx',
#  'takalot book order arriv time long weekend away bush bengreenfield',
#  'saysometh bull domin bull direct whatev want',
#  'steph san kana badli need pleas',
#  'user anoth hand amp feet complet berachah best amp tire',
#  'user way ctf book talk inmat paicip user book club program slugg',
#  'readi awesom beat cool dj danc edm hous goodmus mad',
#  'jpi neg extern environ remain suppoiv mufg blog silver gold forex',
#  'mkf collect jasmin moira crossbodi bag wednesday',
#  'current eat steakandshak minut gotten shake order',
#  'gray sad color make feel grayneedstogo',
#  'difficult road often lead beauti destin anon leadership inspir quot inspir',
#  'usd long posit ad eur sho increas anz blog silver gold forex',
#  'r rockallday user user day nois',
#  'user definit mexican fakenewsal',
#  'user new album releas user break loveherbreakup hotgoss',
#  'stand racism hate americad curs congress hater deplor hate',
#  'sunshin sunshin make sky gray',
#  'someth want say someth make happi game gamer xboxon playstat user e',
#  'footbal actual thing mo watchabl bringbackgladi',
#  'happi hump day humpday life lifestyl wednesday midweek snapchat walru funni',
#  'let say love',
#  'worri happi via user archiveday weekendblogshar happi quot tshi',
#  'great thing never came comfo zone goodtogreat inspirem love',
#  'happi puppi london puppi thursdaymotiv',
#  'know go room one troubl soul draw blackandwhit',
#  'recommend dark amp romanc horror moviegenr ambianc',
#  'user trump use hate putin win white hous trump press attack khan famili g p leader',
#  'one bucket list item tick tonight final saw ice cube live tonight wildlifefestiv today good day',
#  'friend magic potion ewabeach magicalhappydrink ewa beach hous',
#  'everytim wear soccer shi joie fri say look mexican fuck',
#  'weird month final feel posit life late pleasedontchang',
#  'check holiday croatia daystogo',
#  'user night sweet dream',
#  'nyc seven day newyork newyorkc travel bigappl',
#  'life make let make motiv',
#  'fashionblog rooster simul want climb vast expans mountain reach leakag coc',
#  'best mood ever becauseofhim inlov',
#  'happi worri smile love iminlov iam im nice day',
#  'user monaco resto chezedgard grandprixf essai sun lewissuppo user amour love',
#  'bought launch use design think user amp user via user toread letsmak',
#  'sukhbir badal announc offic bearer eastcoast zone canada',
#  'mad chose dj snake zedd edc',
#  'mango wood lett gbp get shop cool home fun',
#  'danger white liber oveurn appli liber men femin',
#  'user user user truli truli pathet mani way user user user noth learn coverin',
#  'monday morn work lake scottieandrussel work love picoftheday',
#  'love rain hope hang around rain water tbt weather bribieisland',
#  'user chosen wrong hors unless chang mind soon end polit career',
#  'user wed impoant celebr life possibl ann hathaway wed love',
#  'icymi shoot orlando nightclub kill polic say debelop gun',
#  'user user snatch past week schoolsuppli',
#  'great aicl right money starspangledbann slaveri apaheid usa',
#  'babi born welcom new world cat babiescat cat newborn congratul',
#  'pretend pain exampl strong person nighti',
#  'user user user user user even dear cuti',
#  'user user mental cultur mentalhealth',
#  'user wish us weekend',
#  'thank freezer thank posit',
#  'user readi lt gt full day lt html gt user user cssday',
#  'bihday cake made mom bihday mom fondant pumpkin chocol delici beauti amaz',
#  'user thank power social media user aand',
#  'user made smile bigbang babi cto',
#  'send good vibe way happi friday tgifriday goodvibesonli becauseimhappi smilemor',
#  'letsgo agent tooeasi day till dlc know gamingforeveryon',
#  'holi citi tissu',
#  'user old mom bihday',
#  'user decid fowoh goldenretriev lcck comfodog workingdog',
#  'user get angri muslim assassin much',
#  'hereeee user ericprydz edc music musiclif edm danc girl',
#  'funni thing humankind watch news feel bad etc back open busi usual good futur',
#  'user keep tell aryan allow rape women troll eod user user',
#  'user speechless come shoot recent guess peopl noth lose respect',
#  'user forecast beauti wave raalhugandu disappear due construct bridg amp there hope com',
#  'user minut trump condemn vile bigot comment surrog carlpaladino endhat',
#  'wish wonder dad father day let rock today red rascal',
#  'user allahsoil vp got multi million dollar bonus averag american lost home',
#  'love abrahamhick lawofattract healthi heal joytrain',
#  'model love u take u time ur',
#  'sign first bikram yoga class',
#  'think thought shine face like sun beam quot smile',
#  'want creativ worker give enough time play success quot',
#  'hea prayer orlando victim famili lgbt commun',
#  'jan interest discrimin affect crimin justic system',
#  'friend forev friend sweden reunion grate love egna hem',
#  'keep opposit user endthen',
#  'love pizza pizzaslic pizzaslic aoyama pizza yummi delicia goodtimeswithgo',
#  'two love beer craftbee dog malinoislov malinoi passion friend',
#  'abund posit affirm',
#  'fathersday father day dad skinni singl buy thing h',
#  'user rickiti rick rickiti rick ole broken wagon look find next mateen jump board',
#  'love citi great day cleveland home calm',
#  'guess user talk progress advanc misogyni homophobia bigotri',
#  'teen girl kill other injur downtown oakland shoot gun mentalil gang orlando',
#  'everyon go struggl pain right keep head keep smile get hope',
#  'good even darl instagram babi bless lipstick makeup fun grate share',
#  'user jake right mani ppl lack power take stand amp drown small mind amp oft evil tendenc past',
#  'realli hate hipocrit politician side deserv better citizen',
#  'user user user environment wellb plan site nothng todo w',
#  'bihday sway bihday sway bihday bihday',
#  'saturday morn go back sleep thetrust comus indi fade away johnmaun listen user',
#  'founat man life everi singl day father day',
#  'user user gut know tonight would good luck',
#  'begin think user tom bradi hater way goe man',
#  'attack orlando caus lot pain mani peopl vengeanc option let comfo',
#  'cute overload let life fill love sweet live long marri life',
#  'head graduat user mechtechplumb futureplumb proudmama',
#  'user user possibl speak topic without bring race bigot user',
#  'model love u take u time ur',
#  'much terribl news weekend orlando christinagrimmi prayer',
#  'make innov nou',
#  'updat social analyt instalik tbt yoga summer fun',
#  'rushlimbaugh incred obama impress via user',
#  'user user peopl fail fellow citizen',
#  'sta pack move newflat',
#  'first love may make feel like love chees shotermlongdist',
#  'user youtu bed two get friendship',
#  'want kind poor sin despis anyon jesu faith believ wisdom',
#  'nice life done tri lovequot',
#  'latest positivementalattitud thank user user user posit',
#  'want spark seriou debat gun violenc releas photo bodi insid club orlandoshoot gunviol',
#  'arriv blagoevgrad fo zaz conc feel umbrela',
#  'user number leader come',
#  'see user tcashowroom yesterday',
#  'user mean mean like',
#  'great way spend saturday relax positivevib california cakesbytheocean',
#  'eur usd could test near term westpac blog silver gold forex',
#  'money campaign ask k donat midnight fight hrc ad buy brokedonald lyindon',
#  'today call champagn friday fridayfeel friyay goodweek client hair',
#  'user user user rightli gop hate trump obama',
#  'user user user user user user user user sunday hug',
#  'us selfi myfriend loveh giannena smile thecomeback',
#  'moment decid need switch control life respons default',
#  'play yiruma kiss rain music song',
#  'simpl true becom capabl burnsurvivor dolbf motiv motiv',
#  'back miss greatfultogod beendoinggreat selfi',
#  'repeat put dog hot car leav heat keep home fuck sake dog',
#  'splendid nosi probabl year wrc rallypoland user user',
#  'hour go music video releas music edinburgh scotland band user musicvideo user',
#  'user confirm dead accord farrah gray pulseshoot',
#  'look journey left right foot stage',
#  'black professor make assumpt entir race whilst speak entir race next week jew',
#  'back music play michael jackson lost children unificationsday may god children amp famili smile',
#  'drakeandjosh buffalo simul buffalo take vicin home wa',
#  'trumpusa call us homophob misogynist realli say jealou us w',
#  'user think suspend indefininetli racist staff',
#  'sat alon let sad sigh openrp bore',
#  'good morn manchest quick preview new gin launch soon one',
#  'tri new user trailn v today although feel similar v v smoother feel great',
#  'kiki felt ignor today user make kiki danc kikid miabbook',
#  'user sourc inspir ideal lyf baba father day',
#  'user congrat thoma new beauti home tehaleh welcom lennar famili homeown',
#  'miss day friend play xbox',
#  'new case scraggli hair',
#  'user love dincwear mum da word user straight saturday brickingit',
#  'bihday sexi girl girl top boy nake',
#  'user one major fan like salti gsw fan need someon',
#  'user chang daili basi week handov user network team soon av',
#  'user come singapor',
#  'sma babi sock gbp get shop cool home fun',
#  'like user video user sjw retard want',
#  'user woh wait user doubledown wife user user veganbeerfest vegan',
#  'user lmfao deadass',
#  'amaz interview bjmckenzi born win bjmuzic',
#  'boasti tuesday last night boom boom harri hype say get',
#  'bihday balayya even age mass look craze fan screen romanc legend jaibalayya',
#  'woohoo kingsland highlandreserv hous famili build ourhom',
#  'outlin theme would poem haha',
#  'decor buffalo simul buffalo take vicin home way',
#  'sold one two paint go get beauti new home week sold',
#  'user msg hope newyear busi end endof tedtalk tedatibm user user',
#  'user slag children love show realli user',
#  'safe say miss marb sit home watch euro listen rain depress bringbackhappi',
#  'brainwash left allow terrorist come america kill',
#  'gd morn gdragon gd kwonjiyong jiyong vip bigbang handsom cute love',
#  'friendszxc',
#  'day till vacat',
#  'secret happi marriag find peopl less attract repo',
#  'python concurr best friend code restructur get concurr celeri develop python',
#  'womenareamaz think induoev superwomen follow dowhatyoulov',
#  'hairi pussi redtub hardcor track',
#  'let season bing begin oitnb myfavorit season weekendplan',
#  'rest peac christinagrimmi loss rip miss fan foreverinourhea',
#  'pictur woh thousand word sundayrewind hongkong travel ladi lawyer',
#  'relax inger followm follow follow follow beach pool relax enjoy coupl',
#  'user countdown begun famili freeevent festiv enteain food stall',
#  'awesom beginn gopro mount super use',
#  'dear istor pleas crash due heavi overload booktim muchlov',
#  'never underestim power good book good wine good food great patio summereven patioweath',
#  'istg best chees ta dayum expens',
#  'morn offic routin never without bff imi',
#  'model love u take u time ur',
#  'theshallow weak attempt cash jaw anniversari',
#  'user non stop elect blame cspan hide year pittsburgh california',
#  'extrem reveal first offici poster poalorigin pa come summer mo',
#  'minut count wwdc wwdc',
#  'user user play ball state polit facad lost princip',
#  'peopl protest trump republican trump fuher amp',
#  'great day noth happi bless thank',
#  'happi sunday everyon sundaymorn sunday peac love',
#  'alway help other never peopl matter clearli quot latenight',
#  'bihday weekend even better xx',
#  'stay strong selflov love ilovem quot quot quoteoftheday happi life wisdom wordsofwisdom',
#  'happi father day boy father sweet love memori user',
#  'aww yeah good bing bong bing bong',
#  'life impoant human spirit truth love give b spiritu thinkbigsundaywithmarsha',
#  'father babi love u happiest father day father via',
#  'user current mood user web develop meet amp hire',
#  'know get old sta get turn look poweool b amp q',
#  'project busi hand happi hand',
#  'user bride woman fine prospect happi behind ambros bierc wed love',
#  'friday xoxosamantha via',
#  'user stop rob innoc custom hard earn aiim guy idea dey manag recharg',
#  'grab besti amp swing hour miss fun eat',
#  'opinion racism degrad peopl base race justifi discrimin open violenc stoprac',
#  'final move today',
#  'user user user way say blogger vlogger',
#  'user user yay fantast edinburgh',
#  'lemm find put boiler month june',
#  'hea goe famili peopl kill massacr orlando',
#  'pre user gig drink passthecourvoisi user',
#  'rescu pup meet rexi rescuepup rexi pupsofsg suicidegirl beauti puppylov',
#  'video get excit futur tech augment futur mobil',
#  'user congrat ur wish come true work user superxcit song',
#  'wish',
#  'hellosunday hope beauti sunday sundayfunday sunnday',
#  'gif listen song sinc age',
#  'nzd usd rise eye gdt price index fomc statement blog silver gold forex',
#  'true home food consid cheap meal impress made restaur',
#  'happi bihday one west greatest tupac shakur bihday rip tupac',
#  'user live life',
#  'hr go fl motionpost reveal mupparimanam feel nervou stay tune',
#  'user littl tast sure',
#  'appletstag compleanno toa cake famili bday selfi smile girl summer',
#  'anim anim tree friend tag anim fana pixiv happi tree',
#  'user happi nd wed anniversari amaz husband user memori year lotstocom love',
#  'slow sta product day get back routin bout fatigu flareup hard spoonieproblem',
#  'love ramdan fast love iftar feel love way feel ramadan pray read quran bless',
#  'eur gbp subdu trade action around blog silver gold forex',
#  'user ngitingtagumpay',
#  'unusu cloudi day elect day picnic friend sunday everyon welcomeludovica',
#  'cloudchas gorilla simul need adapt environ need tear citi mat',
#  'christ aliv vlicob xoxo love grace amen share passion church life',
#  'want leak udta punjab probe suspect polit job jobsearch chandigarh maker udt',
#  'yesterday ozen restaur eatallyoucan',
#  'alreadi tell next week episod gonna give intens anxieti nervou gameofthron',
#  'got noth say assum ahahahahahah',
#  'ordinari girl intruduceyourself',
#  'user may light triumph dark may ramadan bring peac harmoni joy ramadan ramadankareem',
#  'user user els notic suppoer r pageant girl w year intern femal oppress system',
#  'user reason optimist rule world success growth balanc optim',
#  'hate onlin applic even get foot door tell need',
#  'thank flower thank posit',
#  'top crappi day w sign paper hous user pop conc block work amp know',
#  'beauti love live beach beach loveit',
#  'user omg bitch knew gone lil kim actual look like music video',
#  'tgif ff gamedev indiedev indiegamedev squad user user user user',
#  'user user user man even bunch coupon',
#  'way sta day goodmorn',
#  'lking forward water hole watchtow foress user user user',
#  'user allahsoil next best seller book isi islam world word terrorist gwot',
#  'fantast rub steak yum thespicesndteaexchang dc healthi',
#  'followm touch tit',
#  'feel like summer love like live life enjoy healthi sun tan bikini summer',
#  'teenageson reckon gone beyond call duti fathersday prezzi',
#  'user forget user research show sexist men psycholog problem tuckercarlson',
#  'nice specif pedagog chang',
#  'user typic citi fan',
#  'im attract asian ppl bc im asian tell im attract u bc im ins race hoe',
#  'user awlrit mol jealou better cricket pitch life getalif',
#  'prayer go eddi famili',
#  'nothappi carer finish one week',
#  'closeencount fatkind fatkid dese sick tire maybemono',
#  'gymmorgon gym morn strength energi train wingym',
#  'glad arriv safe user',
#  'defin histor oppress histor oppressor privileg',
#  'realli pretend truthseek empower selfimprov heal ihearadio',
#  'final found way delet old tweet might find use well deletetweet',
#  'user view oregon poland usa unitedst holiday dj produc hous',
#  'put vote yet havent share see make smile poll',
#  'user next chapter life sta soon look hous today fianc',
#  ...]

# %% [markdown]
# # one hot encoding and padding

# %%
onehot_repr = [one_hot(words,voc_size)for words in corpus]
print(onehot_repr)
# Out:
# [[845, 2515, 4654, 2797, 1553, 3588, 4654, 2004], [845, 845, 1273, 1050, 135, 4824, 1980, 169, 2267, 3077, 4535, 4240, 3984], [2176, 329], [4435, 3275, 2520, 1615, 2520, 4289, 1395], [4389, 599, 3577], [635, 4712, 2311, 3164, 1015, 4039, 1744, 2698, 919, 550, 2454], [845, 4553, 3608, 845, 845, 845, 845, 845, 845, 845, 1877], [926, 4617, 1002, 1002, 4370, 777, 4617, 4370, 1580, 4088, 4314, 4288, 4427], [3275, 4752, 133, 3818, 4134, 3221, 3420], [845, 845, 561, 176], [2441, 105, 4255, 4562, 1494, 439, 295, 2854, 4010, 15, 3809, 1870], [2797, 4933, 2816, 227, 2965, 4390, 2797, 2442, 65, 3275], [550, 3711, 996, 2921, 3391, 4936], [845, 148, 283, 4442, 3836, 4617, 1861, 4060, 475, 2458], [4738, 2706, 4, 2992, 3481, 3202, 3481], [3055, 483, 3232, 3768, 483, 413, 3037], [1273, 992, 1273, 3470], [4225, 2262], [3114, 4456, 4987, 3872, 395, 845, 845, 3258, 2896, 3820], [179, 1235, 1714, 154, 2908], [2935, 3820, 3830, 2903, 2431, 2308, 1733, 208, 2903, 304, 4719, 3759, 179, 2654, 2446], [4491, 657, 1037, 2628, 3187, 3412, 3741, 4718, 727], [3670, 3391, 1807, 2452, 670, 4913, 193, 4289, 361, 3382, 3507], [845, 845, 551, 4620, 4981, 551], [845, 4739, 1273, 2967, 2452, 568, 4593, 845, 845, 845, 845, 845], [3735, 1111, 2479, 2876, 3661, 3275], [845, 4456, 3146, 4490, 663, 3607, 3875, 928, 3275], [3171, 381, 2864, 4829, 3293, 218], [1807, 2515, 3391, 845], [3820, 414, 3044, 638, 3182, 2452, 1435, 615, 3820, 3129, 1076, 4750, 2362, 4933], [4158, 4745, 3150, 1488, 3142, 1760, 4314, 1840, 9], [39, 4289, 2544, 1933, 1212, 845, 845, 845, 845], [845, 2362, 2749, 3382, 2441, 4712, 3796, 2217, 304, 1689, 4971, 4750, 4642, 1503, 3427], [4832, 1087, 2969, 2637, 49, 675, 4303, 3670, 2921, 1786, 2909], [1410, 2348, 2915, 1518, 2828, 3321, 3227, 379], [2622, 4954, 2699, 4954, 2191, 4745, 1530, 1487], [3182, 1045, 2017, 2316], [845, 104, 2913, 2799, 4798, 2990, 2309, 822], [1615, 1919, 3040, 3609, 711, 4014, 2488, 4183, 2905], [1273, 3760, 1273, 3470], [1010, 3839, 2867, 4183, 965, 4641, 2352], [4552, 240, 4712, 4832, 4324, 784, 4712, 4308, 4503, 4987], [4082, 3374, 4934, 1094, 3391], [1494, 72, 2176, 845, 2176, 2177, 3711, 193], [3275, 429, 2055, 2105, 1204, 3621, 2589, 4057, 2055, 1957], [2646, 3470, 3926], [4435, 3275, 2520, 1615, 2520, 4289, 1395], [4676, 3330, 2828, 4625, 4092], [241, 2477, 3770], [2279, 2931, 4082, 179], [4399, 550, 2181, 1973, 2289, 1828, 2321, 3393], [2176, 3768, 4674, 576, 845, 2176, 4147, 3275], [4357, 2693, 134, 4289, 845], [845, 1370, 3084, 783, 2243], [1273, 2238, 3275, 2047, 4104, 4368, 48, 1839], [2506, 1183, 731, 2763, 3669, 467, 4357], [845, 1370, 1596, 3275, 1124], [1807, 2515, 3391, 3215, 1611, 1832, 2515, 3391, 1611, 1438, 3913, 1832], [845, 1500, 4289, 340, 1500, 404, 1593, 1098, 102], [193, 2209, 1561, 1903, 3321, 3321], [1807, 4183, 2502, 2123, 2673, 49, 1345, 922, 2329, 4183, 2673], [3892, 3226, 3288, 4915, 926, 3872, 845, 4832, 3329, 3027], [2181, 3308, 3549, 223, 1307, 1144], [2365, 2203, 241], [845, 4672, 2927, 4796, 2284, 2081, 4370, 121, 700, 3382, 802], [845, 4284, 2123, 3647], [1738, 4381, 2452, 1183, 1643, 3479, 2515, 3391], [792, 1807, 3609], [2689, 492, 1652, 1505, 2004, 4987, 3275, 674, 3171], [638, 3182, 4069, 2243, 2641, 4704, 2476, 2054], [845, 1690, 214, 3321, 110], [1628, 3894, 3448, 1760, 2728, 3705], [4586, 1370, 1536, 3145, 134, 4933, 2769, 3183, 1911, 1002, 1253, 3588], [845, 1456, 4181, 4267, 2457, 1579, 3819, 3856, 180, 1456, 3448], [4565, 134, 412, 1144], [3815, 959, 4295, 3885, 3856, 777, 4931, 460], [845, 1270, 2428, 845, 481, 845, 845, 845], [845, 4630, 2689, 3820, 283, 3820, 2689, 845, 2859, 873, 40], [845, 845, 1119, 4557, 2921, 864, 1015, 3856, 121, 283], [2594, 3061, 802, 3061, 280, 4758, 2578, 1519], [1524, 2149, 845, 845], [845, 36, 1907, 389, 3680, 845, 937, 4129, 561, 3515, 3790, 845, 2848], [592, 4824, 3382, 3218, 653, 4359, 1973], [744, 4947, 783, 1615, 4947, 2979, 2488, 4070, 1702, 4016, 550, 3079], [4824, 1474, 3227, 2130, 83, 1231, 247, 1124], [1948, 2343, 3233], [3117, 304, 40 ...

# %%
sent_length=20
embedded_docs = pad_sequences(onehot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0 ... 3588 4654 2004]
#  [   0    0    0 ... 4535 4240 3984]
#  [   0    0    0 ...    0 2176  329]
#  ...
#  [   0    0    0 ...  213 4183 4491]
#  [   0    0    0 ... 4127 4468 2974]
#  [   0    0    0 ... 1273  845 4585]]

# %% [markdown]
# # model training and prediction

# %%
embedding_vector_features=40
model=Sequential()
model.add(Embedding(voc_size,embedding_vector_features,input_length=sent_length))
model.add(Bidirectional(LSTM(100)))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 20, 40)            200000
#
#  bidirectional (Bidirectiona  (None, 200)              112800
#  l)
#
#  dense (Dense)               (None, 1)                 201
#
# =================================================================
# Total params: 313,001
# Trainable params: 313,001
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
X_final=np.array(embedded_docs)
y_final=np.array(y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_final,y_final,test_size=0.33,random_state=42)

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 670/670 [==============================] - 14s 17ms/step - loss: 0.1770 - accuracy: 0.9426 - val_loss: 0.1413 - val_accuracy: 0.9507
# Epoch 2/10
# 670/670 [==============================] - 10s 15ms/step - loss: 0.0991 - accuracy: 0.9639 - val_loss: 0.1493 - val_accuracy: 0.9509
# Epoch 3/10
# 670/670 [==============================] - 9s 13ms/step - loss: 0.0719 - accuracy: 0.9752 - val_loss: 0.1752 - val_accuracy: 0.9515
# Epoch 4/10
# 670/670 [==============================] - 10s 14ms/step - loss: 0.0491 - accuracy: 0.9842 - val_loss: 0.1889 - val_accuracy: 0.9448
# Epoch 5/10
# 670/670 [==============================] - 9s 14ms/step - loss: 0.0328 - accuracy: 0.9898 - val_loss: 0.2158 - val_accuracy: 0.9438
# Epoch 6/10
# 670/670 [==============================] - 9s 13ms/step - loss: 0.0228 - accuracy: 0.9925 - val_loss: 0.2950 - val_accuracy: 0.9469
# Epoch 7/10
# 670/670 [==============================] - 9s 13ms/step - loss: 0.0172 - accuracy: 0.9949 - val_loss: 0.2835 - val_accuracy: 0.9486
# Epoch 8/10
# 670/670 [==============================] - 9s 13ms/step - loss: 0.0157 - accuracy: 0.9948 - val_loss: 0.3296 - val_accuracy: 0.9407
# Epoch 9/10
# 670/670 [==============================] - 8s 13ms/step - loss: 0.0105 - accuracy: 0.9969 - val_loss: 0.3590 - val_accuracy: 0.9442
# Epoch 10/10
# 670/670 [==============================] - 9s 13ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 0.3694 - val_accuracy: 0.9389

# %%
y_pred=model.predict(X_test)
# Out:
# 330/330 [==============================] - 2s 3ms/step

# %%
y_pred=np.where(y_pred>=0.5,1,0)

# %% [markdown]
# # score

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
confusion_matrix(y_test,y_pred)
# Out:
# array([[9527,  279],
#        [ 365,  377]], dtype=int64)

# %%
matrix=confusion_matrix(y_test,y_pred)
print(matrix)
score=accuracy_score(y_test,y_pred)
print(score)
report=classification_report(y_test,y_pred)
print(report)
# Out:
# [[9527  279]
#  [ 365  377]]
# 0.9389457717102768
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      9806
#            1       0.57      0.51      0.54       742
#
#     accuracy                           0.94     10548
#    macro avg       0.77      0.74      0.75     10548
# weighted avg       0.94      0.94      0.94     10548

# %% [markdown]
# # test data prediction

# %%
df1=pd.read_csv("D:/sentiment anlysis/test_tweets_anuFYb8.csv")
df1
# Out:
#           id                                              tweet
# 0      31963  #studiolife #aislife #requires #passion #dedic...
# 1      31964   @user #white #supremacists want everyone to s...
# 2      31965  safe ways to heal your #acne!!    #altwaystohe...
# 3      31966  is the hp and the cursed child book up for res...
# 4      31967    3rd #bihday to my amazing, hilarious #nephew...
# ...      ...                                                ...
# 17192  49155  thought factory: left-right polarisation! #tru...
# 17193  49156  feeling like a mermaid ð #hairflip #neverre...
# 17194  49157  #hillary #campaigned today in #ohio((omg)) &am...
# 17195  49158  happy, at work conference: right mindset leads...
# 17196  49159  my   song "so glad" free download!  #shoegaze ...
#
# [17197 rows x 2 columns]

# %%
df1['tweet'][478:485]
# Out:
# 478    @user the right 2 be   without #stress or #fea...
# 479    it is amazing what a day has #surprises #movem...
# 480    caffeine fix. a quick cup of coffee.  #positiv...
# 481       green #jamesmcavoy #atonement #mcavoy   #flim
# 482    #pass #last #exam #made #new #lashes thanks to...
# 483                   @user   #easter! my new hero...
# 484     @user peace an' love ooh ooh ...  #brighton #...
# Name: tweet, dtype: object

# %%
messages_t = df1[['tweet']][:17196]

# %%
messages_t
# Out:
#                                                    tweet
# 0      #studiolife #aislife #requires #passion #dedic...
# 1       @user #white #supremacists want everyone to s...
# 2      safe ways to heal your #acne!!    #altwaystohe...
# 3      is the hp and the cursed child book up for res...
# 4        3rd #bihday to my amazing, hilarious #nephew...
# ...                                                  ...
# 17191  2_damn_tuff-ruff_muff__techno_city-(ng005)-web...
# 17192  thought factory: left-right polarisation! #tru...
# 17193  feeling like a mermaid ð #hairflip #neverre...
# 17194  #hillary #campaigned today in #ohio((omg)) &am...
# 17195  happy, at work conference: right mindset leads...
#
# [17196 rows x 1 columns]

# %%
corpus_t = []
for i in range(0, len(df1)):
    review = re.sub('[^a-zA-Z]', ' ', str(df1['tweet'][i]))
    review = review.lower()
    review = review.split()
    
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus_t.append(review)

# %%
corpus_t
# Out:
# ['studiolif aislif requir passion dedic willpow find newmateri',
#  'user white supremacist want everyon see new bird movi',
#  'safe way heal acn altwaystoh healthi heal',
#  'hp curs child book reserv alreadi ye harrypott pottermor favorit',
#  'rd bihday amaz hilari nephew eli ahmir uncl dave love miss',
#  'choos momtip',
#  'someth insid die eye ness smokeyey tire lone sof grung',
#  'finish tattoo ink ink loveit thank aleee',
#  'user user user never understand dad left young deep inthefeel',
#  'delici food lovelif capetown mannaepicur restur',
#  'dayswast narcosi infinit ep make awar grind neuro bass lifestyl',
#  'one world greatest spo event leman teamaudi',
#  'half way websit allgoingwel',
#  'good food good life enjoy call garlic bread iloveit',
#  'stand behind guncontrolpleas senselessshoot takethegun comicrelief stillsad',
#  'ate ate ate jamaisasthi fish curri prawn hilsa foodfestiv foodi',
#  'user got user limit edit rain shine set today user user user user',
#  'amp love amp hug amp kiss keep babi parent healthcar',
#  'girl sun fave london unit kingdom',
#  'thought factori bbc neutral right wing fascism polit media blm brexit trump leadership gt',
#  'hey guy tommorow last day exam happi yay',
#  'user user user levyrroni recuerdo memori recuerdo friend life triunfodelamor',
#  'mind like bodi like sleepi stillallin',
#  'never entir life',
#  'check twitterww trend trend worldwid bst oscarpistoriu diplom liselilerayakta',
#  'thought saw mermaid ceege smcr inshot girl cute summer blur sun',
#  'chick get fuck hottest nake ladi',
#  'happi bday luci xoxo love beauti pizza instagood mileycyru demilovato',
#  'haroldfriday weekend fill sunbeam everyon healthi weekend',
#  'user user tri noth tri know love rd light fave amp deep river',
#  'never thick women blacktina',
#  'user new user episod tk realli cool year anniversari ep work august',
#  'orangechicken attack bull game realli think head empti around citi side',
#  'suppo taiji fisherman bulli racism tweet taiji thecov seashepherd',
#  'say speak collect alway known show lot',
#  'wish could talk',
#  'food time hayli hot chocol mummi thank god friday',
#  'user snow white gt open gt sleepi sneezi bash dm us today',
#  'bihday shilpashetti wish success yearretail manufactur ladi cloth',
#  'lotteri',
#  'tomorrow fun see old friend shoot someth super fun',
#  'raw food diet benefit altwaystoh healthi heal peac joy love',
#  'user user trump invest billion saudi empow peopl fund isi trumpsahypocrit',
#  'granddaught st bihday tomorrow go pick play hous littl car amp pool today',
#  'happiest place eah disneyworld orlando castl mickeymous likechildren user',
#  'babi dave due born octob fav band time tool play user weekend lol',
#  'love everi day',
#  'user morn sunshin smile sexi bigboob',
#  'world make jesu make happi john word truth faith peac',
#  'food heal bodi doplant healthi',
#  'enjoy sunshin god good orlando sunshinest goodlif bossladi joy',
#  'user father idol prg',
#  'user reason maintain android provid clear basic code exampl doc',
#  'nice luxuryweek monday neweek luxuryweek bestday stayposit fun goodmoment lifestyl',
#  'caus user get live togeth whole week cantwaittocook',
#  'user user user user throw back thursday bih day bro user chege',
#  'thank fun thank posit',
#  'saw cray coz babi hard breath strong yeah babi god kaika medic center',
#  'happen babi duedec',
#  'let thing euro',
#  'time euro onemonth team onewinn footbal intern thjune thjuli',
#  'model love u take u time ur',
#  'lighttherapi help sad depress altwaystoh healthi',
#  'good sunday everyon sunday morn smile picoftheday',
#  'cousin ask alway shawl di ko lang masabi coz po get fat braso get bigger baboy',
#  'believ r willing tri understand encourag amp inspir other b amp grow greater spiritu purpos grok',
#  'time pint see coldplay wembleyyyi coldplay wembleystadium',
#  'current mood goodnight happilyeveraft disney quot bless thank grate',
#  'chioma nobl igw special day chob chob user landmark centr user',
#  'cant believ left school year ago week time ill teach class drama teacher gettingold',
#  'lipo light help shape help shape learn user loseinch burnfat result',
#  'ahhh leav user tomorrow user eforest electricforest plur',
#  'bless hear morn choru good morn peopl friday',
#  'aunti mi find hilari post nigeria enough troubl',
#  'user chapter left book amp nearli complet kruella adaughterstal hard read emot funni',
#  'user thrill work user come month announc soon faceddancecompani',
#  'tri anoth way make sourdough bread one may underproof fail bake',
#  'cool old door window vendor shoploc shopalyssa fathersday',
#  'fathersday fatherday user team',
#  'greatbritain eye sky rafredarrow fli past mall say',
#  'user follow bless love everyon suppo us thx much fish f',
#  'user user user user user lt feed public trough piggi michelleobama',
#  'websit live avon makeup fresh look',
#  'forecast look good weather across bolton',
#  'user happi shoot love monica sweet magazin thanku love',
#  'happi father day father day fathersday dad ilovemydad ilovemyfath love',
#  'stardivariu friday new histori new outfit post fashion look friendsfl',
#  'user final countdown offici us public june st whyfontsmatt usa typographi font book',
#  'happi trust first know lovelovelovebabi',
#  'interview feat grandmast flash ze love messag nurap nudisco music pari via user',
#  'get hour work train',
#  'life right amaz success posit',
#  'social media realiti realli get viual accept seem realli thing ocialmedia',
#  'user seven tomorrow southwestseason final user next week plu scrim user wearebusi',
#  'user user user user user ignor amp ill inform tweet r silli childish amp one dimension',
#  'great see look forward welcom digm',
#  'jackblair na horni hot naughti nasti slut young shi wet nude xxx sexi porn kinki snapshot',
#  'user user u take pour one big cup drink deliv',
#  'happi father day dad hope u great day love u fathersday lovey',
#  'work anatomi studyguid sinc pm still done isuck plspassm',
#  'worri daydream sunlight thunder miss dream distanc silenc pain sweet',
#  'user get readi kubamba father day kambua noel gg moh bless',
#  'ya know guy feel stress donut thing feel happi know follow stick',
#  'pa jk fun memori bff love',
#  'electron music bogota colombia puntohost cedm edm dj fashion music',
#  'back peopl missingperson havingfunalon lone hothl',
#  'l v e sky photoofday moment cool instaphoto paradis good mexico',
#  'happi saturday tune music saturday edm',
#  'mani user alum friend wake shock hear death scsu presid shock',
#  'user disappoint yesterday argument even baselessli accus live mother basement weak bad',
#  'hey user ivanka bracelet feel good profit xenophobia misogyni hatr grabyourwallet',
#  'love saw temporari setup',
#  'happi euro eve euro',
#  'user retweet half day gun owner like hubbi amp respect fanatic',
#  'colourpop',
#  'palladino say feel like say gopathet lookwhatyoudid polit madcow',
#  'save login x broker chang meme love educ univers',
#  'user fursuit fuck hardcor',
#  'someth obvious realli funni laugh girl smile',
#  'fbf sta far user come amp anxiou',
#  'thank film thank posit',
#  'user user user user way oambo see soon sasocp',
#  'user user user alway alway alway somebodi els fault bigot',
#  'begun someth new page amp super daili tarot guidanc',
#  'turn today whitegirlwast dramafre armedsecur',
#  'qatil poetri poetri eid poetri line sm eid ghazal urdu poetri dard poetri beuti poetri follow user send',
#  'rip victim usa prayfororlando terror victim lgbt suppo altogeth pride stand',
#  'grate affirm',
#  'user read aicl yr even dhaba side nation highway grow acr ganja',
#  'drive see greas amp footloos',
#  'user thank steve think quit sunk though',
#  'user today good day happiestplaceoneah disneyland fun walk sundayfunday',
#  'ltpst need vitamin sea beach blue smile',
#  'user today code white summer love',
#  'rainbow wall street good way end train officialrainbowspott',
#  'water',
#  'go great day day choic matter feelinggood proud feelingaccomplish motiv',
#  'user oh ton stuff like eah garbag dump',
#  'found vault never post selfi throwback boy guy love',
#  'happi friday wegotwheel car vw polo firstcar ontheroad whitepolo newcar',
#  'user togeth christma pl amp follow user nation day action feb amp',
#  'might libtard libtard sjw liber polit',
#  'withasumi yesterday shot disney disneyland enjoy',
#  'user game throne longer sky box set mad help',
#  'user straight chaser music video',
#  'u nonhockey peopl hockey babe ruth die gordi howe beyond myth legend hockey lost mr hockey',
#  'linkedin anyth work give free membership canadian australian british veteran justusvetsatm',
#  'michelleobama look bit dishevel think spend retir visit obama',
#  'dinner lukey boy lovehim holiday orlando clear creek circl',
#  'wait watch user everyon user even',
#  'user hahaha good point total skip celebr dad ask',
#  'cat bag fruit ninja steam htcvive',
#  'user nation german bestfriend day mayb',
#  'realli good cook credit user mash potato mac n chees',
#  'local mp downgrad hospit savethealex',
#  'pretti much best advic ever hydrat zerofucksgiven friday sorrynotsorri live',
#  'model altern tattoo pierc old town bellevu',
#  'sent msg aunt peru told wish grandpa uncl happi father day includ dad',
#  'day user best',
#  'peopl protest trump republican trump fuher amp',
#  'work attorney white offic shot philandocastil remov black judg presid trial',
#  'phil spencer critic soni cours els would got slap face soni huge million dick',
#  'user think sa pretti great wait show twodaystogo countdown shhh bringiton',
#  'w user user user cafeexpress stanupcomedi crazi',
#  'user trump long histori explain thru nevermypresid theresist',
#  'happi mother day ppl',
#  'bff liverpool first stop user flatwhit coffeelov bestfriend',
#  'love',
#  'tom hiddleston aka loki excus spell new jamesbond scaryinthor bestchoicefornewjb',
#  'watch movi alon',
#  'one think could bit punch gameofthron',
#  'princess one princess sadli',
#  'cant wait icon weekend wait final get one tatoo icon',
#  'laugh fact mfz use app talk u feel insid peopl see haha',
#  'sterl attack bull chase leav lot despit fact strong sourc fo',
#  'final found way delet old tweet might find use well deletetweet',
#  'user user user never doubt pa mani vote sad america',
#  'cut anyon english dna half well find written insid',
#  'user vip ciniworld caz user',
#  'see war craft imax warcraftmovi imax woohoo',
#  'model love u take u time ur',
#  'user burnt garlic bread devast',
#  'model love u take u time ur',
#  'user look right cameraman grab kati arm amp said talk wow everyth tv',
#  'user user user user user held one march great cpd everyon',
#  'look african news boredem stumbl upon user oh god site racist fuck everyth',
#  'user user dana devest troubl',
#  'gorgeou posit affirm',
#  'user oh admit small staff flipflopp disgrac',
#  'happi instagram instagood instagram instapasspo instadaili',
#  'splash around dog bestdogev swim healthi goodvib yoga fit',
#  'peopl old bore resolv bulli other twitter',
#  'user love',
#  'user much violenc last euro wonder happen brutal side come back euro footba',
#  'mess nail',
#  'lighttherapi help depress altwaystoh healthi happi',
#  'aww yeah good bing bong bing bong',
#  'selfi srelfi smile selfi followm f f polishgirl polskadziewczyna',
#  'vera rubin overcam invent whole field scientif studi diversityinsci scienc steam',
#  'user user user user user sorri read much pain',
#  'user draft b pick uni liverpool recognit user user user',
#  'gbp usd upsid limit around commerzbank blog silver gold forex',
#  'childrenoftheworld bull domin bull direct whatev want',
#  'kaya class',
#  'model love u take u time ur',
#  'model love u take u time ur',
#  'london selfi smile love photooftheday picoftheday london londonlif user',
#  'need prayer right take grandma death well shock whyher',
#  'user user user seen gay gorilla mindset nonsens tout dershowitz clean',
#  'user think go best match ever watch wed oldgirl auwfc',
#  'user user unfoun current gop see reagan like',
#  'monday instagram instagramm motorspo photograph formula user',
#  'great day littl man tkd grade amp crack swim lesson top wale win wal',
#  'sorri bear user time',
#  'user wait pubcon user bestconfer oct digitalmarket comingsoon',
#  'user monday u model boob tit urbex televis sexi retweet tight pantyhos desir touch',
#  'glad live place',
#  'fam ili fast famili likeforlik like like lfl togeth happi love',
#  'starship nickiminaj secondcov singitfohevin singersofvin sing musician music',
#  'thrill posit affirm',
#  'user make someon happi today mind damn busi life live inv busi love',
#  'paradis rooster simul want climb vast expans mountain reach leakag cock w',
#  'pat student want snapchat adrianmcqueen snapchat ucumberland colleg',
#  'client need brainstorm socialmedia altrincham',
#  'disney gator attack year old boy found dead disney',
#  'price stolen payment card record drop ransomwar rise',
#  'got free slice cake fav cafe tgif',
#  'user box pictur contain singl inflat prep school boy sex doll',
#  'user relax peac',
#  'user first user user new custom user paner drupa hall stand c',
#  'love instagood photooftheday top tag tbt cute beauti followm follow',
#  'sinc last time drank hard liquor officem',
#  'user older peopl see pic nose rememb smell close impoant site like',
#  'socialmedia may hottest may record nasa',
#  'say abl attend user year due hotel cost hope attend next year tho',
#  'hea spazz ship hahaha doctor',
#  'nearli readi nohamptoncarniv',
#  'mani innoc peopl die ceain politician choos ignor hate refus even discuss gun control',
#  'almost week sinc saw stroke',
#  'user sta newbook visit jfk museum inspir',
#  'intellig posit affirm',
#  'heal lawofattract loa altwaystoh healthi well',
#  'fatal truck crash kigali highway leav peopl die instantli around kicukiro centr rwanda',
#  'macbook gorilla simul need adapt environ need tear citi materia',
#  'marshmallow time fire son love',
#  'user believ much use care peopl thought like lol fuck u fuck wtf fuck',
#  'jealou best mother mamatii je aim cute nice',
#  'alway amaz come unexpect place like local cafe today irish got first muslim gut',
#  'icedcoffe user coffeeblogg coffe thecappuccinotravel',
#  'user ever get lyme war yeah help',
#  'p pupil readi ymi music extravaganza',
#  'made laugh hard angri bieber dontknowwhi fridayfun user',
#  'grow old along best yet robe brown wed love',
#  'usd jpi bull sit tight handl fxstreet blog silver gold forex',
#  'user fail terribl control drug must punish elector user let initi blue fb',
#  'user user never see store anymor ask autograph said hi time',
#  'rest peac christina rip ripchristina christinagrimmi love miss',
#  'alway watch one user race inspir train still got solid month yet st race',
#  'see pictur dog today smile face tweet good',
#  'woke af realiz world around chang sigh',
#  'love return coollim starbuck cool lime feel fresh nice great drink',
#  'could wors embarrass unfoun traumat bitch black live matter black peopl',
#  'tech buy bitcoin debit card',
#  'happi father day father fathersday sunday famili',
#  'thank freedom speech thank posit',
#  'justinb gorilla simul need adapt environ need tear citi materia',
#  'user user still fuck bullshit give bigot platform spread vile hate boy',
#  'user girl boy p user user sissi user user user user',
#  'bihday flower saturday flower love je b jewelri studio',
#  'user user even think wear dad jean',
#  'anoth nerd friend ban person believ snotopenmind ohwel',
#  'user user user alway race religion wrong w america',
#  'sometim take realiz person realli fit life friend soon boss',
#  'back day job shane lowri gt gt',
#  'fathersday strongest patient kind understand person know',
#  'third wheel cold stone right use buy one get one free coupon',
#  'simpli assault equal spit someon author got charg wrong guy walk',
#  'user get tweet marriag wale',
#  'user video refer sen warren pocahonta stabl pattern ignor',
#  'make meer inspirati kijk op life',
#  'hous taken footbal time get read user alway love book',
#  'user end day gotta',
#  'cleveland fan look',
#  'bubbl posit affirm',
#  'user get readi deliv featur address bright eye group youngster nervou',
#  'user smoothi glass half full comeon',
#  'wednesdaywisdom make sure ignor true happi life',
#  'user trust broken right',
#  'iftar happyhous besti friend chillin iftar goodtim tgi friday street',
#  'realiz look littl cross eye licens lol',
#  'go fun week day csikraken construct',
#  'bihday sweet littl mermaid time flown quickli believ',
#  'arrest daili us polic civilian encount daili shoot abus extrem rare tho',
#  'thank inspir thank posit',
#  'wish kpop aist never come countri abl see perform broke ppl kpop',
#  'want go anywher sunday sinc ghosthuntersintern destinationtruth chillernetwork',
#  'father day',
#  'thank health thank posit',
#  'peopl judg colour english accent',
#  'lostnfound got togeth want seriou long term monogam relationship',
#  'cc without aciiii eki liani fetti cc emerg team friend famili like love',
#  'black live matter today day',
#  'usd jpi remain weak blog silver gold forex',
#  'charact custom confirm pokemonsunmoon e',
#  'user user emma great meet yesterday email oppoun alreadi',
#  'poor babe miss water play morn school figur water play afternoon poorbabi',
#  'let light hmmm prefer l spotlight vibrant aliv joy sparkl',
#  'today good day love goodday smile goodangl instasmil instagram',
#  'realli terribl mass terrorist attack usa night club black day user user user',
#  'user user hear bigotri homophobia sexual assault woman treason lie hear',
#  'know posit affirm',
#  'right one suppo women nutrit romanc love date soulmat sexi',
#  'hate crisi among mani other presid elect user amp co capabl',
#  'user wonder saturday flower day vine user',
#  'guess chip hill teach kid spell mp might littl hard u',
#  'model love u take u time ur',
#  'got wine v happi',
#  'user deserv much better understand endors stand much',
#  'user thank reach issu resolv turn site fulli compat safari io maco',
#  'happi bday jb yesterdaycelebr fambam feel happi',
#  'bihday libat feat user gay boy cute friend love',
#  'user user bihday majesti',
#  'sleep cri',
#  'user live color check new tote bag color life totebag inspir ht',
#  'thank much user realli feel amaz',
#  'user pimp hoe hooker point documentari brent owen cathous seri kid lol',
#  'goomespa divulga oeparceria inshot girl cute summer blur sun fun dog hair',
#  'sad true true',
#  'anim cat cat grumpi cat happi camper treat play',
#  'aww poor ednahhthepug missingmommi sit wait time',
#  'nice deliveri today manfrotto peakdesign photo photographi tripod strap bag user',
#  'smile filter instamood picoftheday behealthi summer bliss bitchpleas',
#  'pre order user browton beautyblogg icantwait',
#  'user luther vandross danc father father day',
#  'enslav anim okay',
#  'dark',
#  'ah man sunday come round quick enough thestoneros',
#  'got first user liquid lipstick love girl',
#  'first bubbl yr old self champagn celebr thank pete gemini bihday inde',
#  'user patriotwatch sherm new year gap auspol rwnj drunk refuge asylum',
#  'user accept fact appl lost innov sta rip android',
#  'shock amp hear christinagrimmi past away thought amp prayer rwith famili time ripchristina',
#  'user hey user love music realli perform murder azerbaijan dictatorship',
#  'new ted baker ski top surpris hubbi lucki loa lawofattract',
#  'user love hello kitti model pink girl girli yolo smile pop',
#  'user user ur gunna miss',
#  'meet today volunt run user local librari went kid givingback pocintech',
#  'whenev sad close eye rememb happiest moment life life lifequot thought',
#  'user wait see iron maiden first time next sunday user',
#  'user never previou secretscreen starmoviessecretscreen shh come',
#  'mikoto suoh kproject mikoto vine cassidytheduck',
#  'thought factori left right polaris trump uselect leadership polit brexit blm gt',
#  'user user user user user sunday',
#  'user biographi step cousin denis got ear mite use payphon',
#  'merri behappyandsmil behappyandsmilealway behappywithm likesm',
#  'user tgif ff gamedev indiedev indiegamedev squad user user user user user user',
#  'user go eat shit dog anti american piec shit bet dad fuck mouth trump nazi',
#  'realli happi graduat childish shit graduat done',
#  'would live life grate compass love one anoth without',
#  'mani hash tag',
#  'tyler ward amp cimorelli cover pharrel william music video',
#  'huaweiceifiedspecialist pre sale accessnetwork deliv ye stress sno',
#  'look forward user bean caramel macchiato definit burnt memburi servic',
#  'user user oh word think awar ghastli there someth broken soul need',
#  'user tap gratitudejourn benefit without journal entri pressur gratit',
#  'user user suppos confirm user even read teleprompt',
#  'great user screw job user cannot catch break impactonpop impactwrestl',
#  'user tomoz nite user hit stoke go fab night glad im go besti user rdr',
#  'last formteach lesson byeby year',
#  'care care alon',
#  'way door counti wisconsin weekend vacat car foreverdr indi travel vacati',
#  'user poor world',
#  'realiz laker fan make u hate everi western confer team cant root dub impetti laker kobe',
#  'mind boggl dontunderstandtheconswqu',
#  'user like true fals stephen keshi die na waoh life eh one thing dey rememba abt say dey alwaz chew gum',
#  'trigger impuls decis strike haha netherworldforess tier',
#  'alway ministradesanidad',
#  'user user user singl word requir wast everyth wha actual',
#  'user mercuri engin amp mercuri cloudcov truli attend prestigi event data datacentr',
#  'cant alway alway posit inspir user gepaforum',
#  'user tbt capetown tablemountain dad ghel bakh bihday lafamilia',
#  'new tenant collect key user propeyh move apament',
#  'user see u soon user stratton u attend come find us wanderlust fashion',
#  'think happi stay happi',
#  'user wait join us garden walk user',
#  'ye today day user get giddi orangeisthenewblack season obsess',
#  'user slfl conc week away x',
#  'saturday peopl hope hungov listen newsong band unsign',
#  'recogn amp acknowledg relationship god give need succeed',
#  'book tick see cha amp dave user wait user',
#  'wonder wifi work anymor wifi wifiproblem wifioverload wifisuck suck network',
#  'idea stupid comment make invit respons death sideshow',
#  'check user daddydub super father day u best father gr',
#  'black live matter group black extremist',
#  'final found way delet old tweet might find use well deletetweet',
#  'raini day blue got get fishtaco wednesdaywisdom manhattan lunchbreak dontworrybehappi',
#  'user spend life peopl make user quot inspir user',
#  'good news digitalmarket campaign use facebook ppc extrem annoy rule socialmedia',
#  'first ever time govern build oireachta leinsterhous dublin parliment',
#  'thrill posit affirm',
#  'would like thank peopl follow realli appreci author novel writerslif book sciencefict creativ',
#  'user user yeieee jito ya haro bt ur gang alreadi wo million hea fir bhi hope aapka gang jeetey',
#  'make choic better self selfimprov betterlif anxieti happier struggl behappi',
#  'user typic ghetto po politician refus take paint cop poray pig feder bldg',
#  'new addit newaddit fblogger',
#  'thank transpo thank posit',
#  'latest knit clio daili thank user user user twitterstorian',
#  'toptweet like one venusexchang',
#  'keep compani borderjack cuddl',
#  'user user love ron definit peopl rank amp file complac worst',
#  'father day samsung galaxi shakey usa',
#  'model love u take u time ur',
#  'thank love thank posit',
#  'user hello pm warm oman see share sunshin user',
#  'summeim gorilla simul need adapt environ need tear citi mate',
#  'lesson happi life via user',
#  'got noth word weep orlando heabroken',
#  'nope uncl buster sound like jerk trumpsamerica',
#  'look old user harrypott user expens small set alreadi open use sodisapoint',
#  'nice user user readi user come oakland marijuana busi boom california',
#  'u rip front bumper mazzi curb day buddi',
#  'girlz wanna fun girl babi love selfi',
#  'easter meanwhil white hous',
#  'lighttherapi help depress altwaystoh healthi happi',
#  'weekend sho amaz time friend famili summerisher lovedthisweekend',
#  'user littl known fact miller lite ped list lbjdrinksonlyjuic',
#  'user user caus lost',
#  'still women wow',
#  'user first day new diet gone well nice healthi salad tea relax product star',
#  'okey know latest tweet bit clitchi hey like u care idontcar',
#  'brutal rule new year manu close manu auspol australia refugeeswelcom nobord',
#  'find awesom shi sho broad user one',
#  'sta read last day first sign summer',
#  'user sad guy kill warrior team soon',
#  'user agre time chang tune floor vote user user user user',
#  'tbt age sixteen success posit quot choic kind love thursday win',
#  'father day love dad may live long ameennn lifee',
#  'user tweet seriou still comment',
#  'user user user user saturday',
#  'coolestlifehack brazilian gold frog smallest frog motiv',
#  'user come soon amazon coloringbook oliviagraceowen',
#  'chatter girl guid choci alicia marco birong radio sholi click link',
#  'hors maximu',
#  'littlest thing make',
#  'user believ man jose follow hope guy crush baltimor tonight joeybat longbal',
#  'en rout happi monday monday freshsta newweek newm glassalwaysful',
#  'frobabi frobabi naturalhair babyfev melanin love famili cute',
#  'nakedbusti user user user love much user user user',
#  'think beauti tricoloredamericanbulli bluetri pitbul babi',
#  'pilat perfect sunday kxpilat getfitordietri boomerang kx pilat hampton',
#  'god see u wan hype father day smh',
#  'said b world encash wherea india loos legaci due bicker amp politicis yoga',
#  'photo last year',
#  'gotta love staffi doglov mansbestfriend',
#  'brisk vagabond night dayz black mamba ng web ukhx int next gener web hardcor',
#  'user thank manag',
#  'user user good morn dearo saturday',
#  'honor present user three megratrend int l student mobil aiec',
#  'thing wors put word mouth dead peopl taunton hitchen atheism',
#  'spring green latest auspol elect news friend victorian green springst auspol',
#  'instracistclown meme instagram funnyp nochil funnymem chill de',
#  'say dad made better dad say dad gave brother amp niec nephew',
#  'user kid afraid go wait',
#  'dishwash origin draw',
#  'see new webpag orlando file goodread goodbook bookclub top medicalthril',
#  'see ritzpari reopen lhw showcas amaz even royalpalmmarrakech bchotel',
#  'play game joke',
#  'play joe bongiorno mystic music song',
#  'hope wonder weekend monday good sta week',
#  'summer seem last forev summer walk sunni magic beauti natur sky',
#  'tri someth good alway end feel like shit hate',
#  'goodmorn uk today world need love hate less peac smile',
#  'user gonna stop tri grow beard give rest leav pro',
#  'bihday favourit brit awesom time bbqing drink',
#  'tomorrow sta plan niec nephew babi shower',
#  'look forward user repo ccm due public month',
#  'thoughtcast sac photooftheday music instamood photographi instadaili nike famili design',
#  'user absolut pathet user trust',
#  'user right without stress fear human right live',
#  'amaz day surpris movement',
#  'caffein fix quick cup coffe posit appreci friend love creativ',
#  'green jamesmcavoy aton mcavoy flim',
#  'pass last exam made new lash thank studiia lakshmi student',
#  'user easter new hero',
#  'user peac love ooh ooh brighton woopwoop busker drummer kidsdrumm brighton',
#  'user user bonn f te jeff bihday happi bihday jeff happi bihday happybihdayi h',
#  'god help parent lose child antonyelchin',
#  'somebodi tell user thepeopl chose user hispeopl choos trump big differ',
#  'awesom humpday vibe wellbeingwednesday morn motiv',
#  'winner harriet sturgess receiv iow festiv ticket winner domino',
#  'step age healthi',
#  'put tear muslim muslimwomen islam america americanignor',
#  'thank abl see thank posit',
#  'word factori race denial prevent heal southafrica leadership transform inequ gt',
#  'user father day',
#  'user badventcalendar day nov trump elect donat f kin save',
#  'happi father day daddi daughter danc sweet love dad fathersday user',
#  'fed provid inadequ mentalhealth care firstnat intern memo thirdworldcanada',
#  'latest unsw daili thank user user ocean',
#  'well yvr pa time head back real life yow great trip overal much done ellatravel hotweath',
#  'old guy sleep safe amp',
#  'happi friday shot user blog blog blogger friday fashion style',
#  'father day amaz daddi amaz fianc loadz love kim mark nd morgan xxxxxxx',
#  'user happi joy sorri deepak follow love brief releas',
#  'bestsel user motiv never go bed without dream wakeup without hope',
#  'healthi lunch go botan nutrit skincar health',
#  'user user time go make polit',
#  'user much appreci dear probabl issu wrong time thank suppo standard',
#  'user happi place smile inspir',
#  'user preorder user playingitmyway autobiographi avail nov th ex',
#  'resili capac recov quickli feel deflat beat self past stay',
#  'new diari dairi love write amaz love quot wordsofwisdom word happi',
#  'site lt freedom isi ignor amp selfloath sick bunch',
#  'user user user oh boy sta unattribut depend innuendo fear bait weak ralli cri',
#  'love friday ilovecarnivalseri hour weeekend fridaychil chilln',
#  'anoth sneakpeek final prepar user next week',
#  'user user myopic guess money mean peopl need leav coach forev year',
#  'realli quick minut flower paint love old palett',
#  'user good old fashion public shame order',
#  'user user sure sleep w follow everi lap know user fav',
#  'refus bake cake convict get convict cou sell abo babi pa amp get reward',
#  'life right bless oppoun career',
#  'marathon bull domin bull direct whatev want',
#  'everybodi necessarili want admit like gej asham associ wt',
#  'thank laughter thank posit',
#  'weekend amp ramadan everyon tri find dream propey weekend us dubai uae',
#  'live carnabi store seen anyon onion kitchenlif',
#  'sat watch user',
#  'twitter kind recent go ignor',
#  'user troubl updat blackberri passpo os alway stop instal need help',
#  'cook book come soon chef b lander share hit recip privatechef',
#  'actual argument hatr rm reso name call raider',
#  'architectur attack bull game realli think head empti around citi side',
#  'user final found way delet old tweet might find use well deletetw',
#  'cuti fun manli sydney hugo friend sydneywint beer laugh',
#  'need sleep laughter antidot depress',
#  'great wait long final get join pay wale togetherstrong bbceuro',
#  'happi work confer rig ht mindset lead cultur develop organ work mindset',
#  'close book wed date cannot wait share pictur u beautifulhighbarn',
#  'one week exactli edc',
#  'today perfect day happi lifecoach reinventimposs',
#  'user th amend blm discuss thank user',
#  'find fob poster decor room poster falloutboy alltimelow so',
#  'bob marley sang song human youth th day knw coz use smoke weed',
#  'user utterli disgrac parent deal unimagin tragedi internet help',
#  'back work kinda lazi day routin lazi lazyday friday fun food',
#  'user hope u guy readi request user rage callofduti game youtub ragen',
#  'time tomorrow user get see user',
#  'amaz health benefit cucumb healthi altwaystoh',
#  'say got love instagood tbt follow cute photooftheday followm',
#  'offici unemploy hahahaha great bless graduationday',
#  'say user exclus mix ditch label drop next week',
#  'user lt listen beauti best friend user sing amaz voic lt lt lt lt',
#  'get fit summer aomagazin de fit model girl hot beauti sexi love cute summer fun',
#  'imagin grown man want hooligan',
#  'dazzl posit affirm',
#  'delicioso instamo instafollow instaiqq instaiquiqu love',
#  'challeng aap claim punjabi drugaddict dare prove',
#  'cr gmm grammi offici today vedio mv music feelgood like like like',
#  'healthandfit attack bull game realli think head empti around citi',
#  'r musician horribl w grammar teach grammar music school',
#  'brook stallion baaaaack welcom stay pleas brill',
#  'user agre sentiment orlando neverpolit bounc wall furiou impot despair worstopost',
#  'sale piec day princ ceram plaqu reg today easel reg today father day',
#  'burlap farm dog fun dog anim cute funni play hay',
#  'aud usd sell ralli westpac blog silver gold forex',
#  'love life lucki give thank fact often',
#  'good night faith ever vaitacacommafiasdv',
#  'old old fashion love cool perfect nice crazygirl smile card oldschool',
#  'user good way protect user account activ fa bad doesnt work germani user fix',
#  'mine cider weather',
#  'model love u take u time ur',
#  'im sad lost soccer game penalti kick bad call badref soccer',
#  'user safe flight anak may god protect throughout journey',
#  'introduct happi day day',
#  'even orlando notagain',
#  'haileysporn na sexi shi porn horni nasti naughti slut hot xxx nude wet kinki young',
#  'week rehears sinkthepinkfreakshow final user',
#  'special train offic stop two angri dog without violenc video',
#  'stay grandma help surgeri day crazi plu without internet',
#  'rosi redfield next mgcb user',
#  'woohoo hotel book user brew amp bbq littl excit tri amaz menu',
#  'readi school firstday collegelif',
#  'queue',
#  'life simpl happi laugh sad smile alway',
#  'zealou posit affirm',
#  'user user one day day us made terrorist attack india three day imagin ind',
#  'bihday licor caf',
#  'thank memori bungi think done destinythegam riseofiron x make',
#  'user mock citizen immigr work hard earn citizenship wow take benefit freedom mock',
#  'trump alli made remark toward obama cnn carlpaladino',
#  'amp grate money come increas quantiti multipl sourc continu basi',
#  'final found way delet old tweet might find use well deletetweet',
#  'user got place done user time plu user marathon never london goal',
#  'beauti cornwal timeaway peac countrysid timetothink calm water green',
#  'despit setback shape good month anticip',
#  'bird look cool hell ax kid draw year young',
#  'user user black folk becom enemi oppressor wonder chimurenga woh',
#  'enjoy sunday relax mallif coffe sundayfun relax',
#  'sound like user hate st amend thinskin crybabi',
#  'thando thabeth bae bdae mem user',
#  'madashel join',
#  'father day frnd',
#  'user user take long',
#  'trump media normal kkk alternet',
#  'play karen mari garrett daydream melancholi melancholymus',
#  'van jone tri walk back white lash remark trump suppoer tcot',
#  'goodmorn sunday like like likeforlik happi morn selfi trytobebett',
#  'today desneysea friend sunni tire',
#  'one like option someon els clear sore euro spain smile',
#  'enjoy russian rock music clean kitchen make popcorn lemonad ye est',
#  'user elect difficult gop consid po dem dem consid po dem face deni',
#  'today sta thought lot posit think plan today',
#  'fine william non relev',
#  'head gulliv first fenc competit user user user epe welshfenc',
#  'via user goodenough healthi holist yoga gestalt therapi',
#  'happi anniversari crisa',
#  'user also leav man card',
#  'user know user regist amp could meet sultan beingsultan',
#  'want holi wholli commit god result greg lauri',
#  'n healthi flower everywher bother look henri matiss',
#  'mmmmm understand corn icecream edm edc beat club dj djlife waitfohedrop',
#  'user user user user user feel see wife pass home yr',
#  'super fun day set lovethiscrew evokeproduct servin old school photooftheday fun',
#  'love happi hour user amaz cocktail brixton love',
#  'gt bihday special day say bihday us great price',
#  'user sta day right happi optim posit posit love',
#  'thank laughter thank posit',
#  'user user user listen fbi director seem though get talk point obama',
#  'see gay lesbian tran murder see human bee slay other human orlandoflorida',
#  'awesom weather awesom journey world heritag kalka shimla toy train user feel life famili',
#  'sparkl posit affirm',
#  'user spec belong us babi smile magpi glass',
#  'sad lovewin fightback orlando fuckhat',
#  'al fin viern meesperaunplanazo ganasdeviern ganasdeti friday modoon',
#  'user wake smile tell today day tuesday felizma flower flower spring g',
#  'eat healthi live healthi everyday fixwhatsbrokenin word eathealthi live healthi bodi mind soul spirit',
#  'quick fix improv mental health tip life',
#  'user good luck champ cheer alway',
#  'user got meet user user wait hear sing great way sta weekend music',
#  'user thank santa best christma present ever cdnpoli abpoli yyc yeg canada ottawa user',
#  'happi anyon littl choic make user',
#  'flower raini day london britain weather flower vibe',
#  'racism us amp netanyahu commit genocid explain bbcnew msnbc npr cnn wsj huffpostpol nyt wapo',
#  'amp movi play weekend lancast counti lancasteronlin',
#  'happi father day great dad nascar year happi father day dale earnhar',
#  'ty gt user user user user user user user midweek',
#  'happi day',
#  'see video allig sight walt disney world coronado spring reso grandfloridian gator orlando',
#  'user bluntli tweet cologn polic user announc racial profil main station wow',
#  'life make let make motiv',
#  'spectrump king led unveal brightest led world led cannabisgrow',
#  'user user let go ok',
#  'repres boingo mediaplatform hitecnola next week monetizewifi wifi hitec digit',
#  'charm posit affirm',
#  'much',
#  'day final get meet ms yee morn even though',
#  'babi strawberri texasstrawberriesarebigg',
#  'user grow dino size cave cricket amp wolf spider tho hu',
#  'user sunday morn classic play clubhous love smell coffe member sunday fathersday',
#  'tuesday how go dead flipflip rip cb radio',
#  'special deliveri go p tomorrow graduationbal farewellclassof ticket',
#  'best gift god ever bless grate bless inlov grate',
#  'sex video sexi ladi fuck hard pic',
#  'think old friend unfoun circumst today send love good wish hope futur',
#  'genuin posit affirm',
#  'suck singl loyal faithful girl get hu singl',
#  'pick overwatch pc battlenet id chillmast',
#  'user user yet make see tuesday headedto',
#  'sad dukhi shairi urdu shairi love poetri gazal nice poetri daili free poetri dosti msg plz tri follow user snd',
#  'lighttherapi help sad depress altwaystoh healthi',
#  'saibaba day devote user om sairam',
#  'user user user us gun law',
#  'monent soldier famili countri',
#  'alreadi hit trail tomorrow nbjc jeeplif jeepmafia jeepnat jeepgirl',
#  'crazi hdrfusion dope lose game gt',
#  'tell old stori friend bring back good bad memori warstori stilldead',
#  'trainhard polar bear climb race angri polar bear climb race polar bear live cold place lo',
#  'user kudo compliant itaxnirahisi proud taxpay',
#  'father day one',
#  'user ceainli tip point countri',
#  'wit year old grandmoth tear huful word',
#  'user wine wed user wine cellar vineyard famili heritag wed drink hunter',
#  'jb mama role r u im ss im u see kettl smile sun jb know u amp sad shahada amp fri',
#  'saturday pay hawaii collar drink pay saturday sunnyday friend luv gf',
#  'everi man want order need first understand happi',
#  'sinc vote right act dem blame republican biggot new buzz word racist',
#  'fashiondiari bull domin bull direct whatev want wh',
#  'want photo user smile live model babesinabathtub lamod',
#  'bg amp e ubi',
#  'daddi girl father day',
#  'takeaway order',
#  'user obama amp hillari divid america arrest made burn black church black suspect arrest',
#  'omg sad user dead understand shit fli away angel rest peac idol ripchristina',
#  'michel obama ape heel case begin donaldtrump america',
#  'shock loss great talent hea break usa',
#  'user punjab green revolut drug revolut couesi akali congress udtapunjab',
#  'starv love right see love one heaven',
#  'p e n today pm longweekend',
#  'ala life isnt easi press comput key',
#  'fave girl london unit kingdom',
#  'use power mind heal bodi altwaystoh healthi peac',
#  'user beauti work user congrat debut ep possibl teamtutti lovealwayswin',
#  'thank love follow glad share fight depress keefight',
#  'eight day week love beachwed love life beatl boatard umasemana',
#  'biggest dream came true today detail come tonight',
#  'user watch user snaptravel stori user make hope fun barcelona',
#  'say offend insult yet tri back like victim white privileg',
#  'time yesaward winner announc',
#  'state black sinc user growth win debat either user',
#  'week tiu tiuteam bikiniseri letsdothi summer exercis toningup',
#  'find place',
#  'user order penni lane maxi user kittenish line bc summer sale good pass ship q',
#  'long live king mad draw aist mad depress pencil',
#  'ur tryna lighthea amp ur cowrker watch detail documentari breakrm tx execut firstworldproblem',
#  'big pictur',
#  'holiday plan januari week book work beachhut travel',
#  'love follow entrepreneur learn filmmak craft',
#  'bihday ball game redsox boston bihday',
#  'got user illuminatebyashley mail wait use user',
#  'user good morn user jiyodils rj kaik morn piyusha',
#  'go sta move thing new room monday better sta pack dreamroom freshsta springclean',
#  'see america',
#  'road first festiv year bksfestiv letthepaybegin',
#  'fathersday open p delici special amp complimentari cocktail dad',
#  'n healthi never want impos limit work genuin love tom hiddleston ff twhiddlesto',
#  'miss small human noth good without u girli snug',
#  'home cook ya boy fit gym thejurney healthi wealthi wholefood',
#  'alt right promot new kind genet mt user',
#  'current mood tea currentmood wetweekend sunday travel teajenni adventur',
#  'anoth contend join tournament pl allianc join us congrat counterstrkeglobaloffensivetourna',
#  'true motiv drinklifein lifestyl freedom makeadiffer',
#  'friday crack follow user user user user user user user',
#  'happi friday selfi',
#  'messag thegreatest life fallen deaf ear louisvil violenc return week peac',
#  'user brought aluminum equip collisionrepair aimesdoesitbest',
#  'fallout shelter head pc juli fallout get new dlc via user',
#  'thrill posit affirm',
#  'like stat point meaningless life second day bout hour loser',
#  'user go',
#  'mani toy adv show narrow limit genderstereotyp studi warn via user',
#  'book see secret life pet june cineworld',
#  'figur pregnant probabl one loneliest time life pregnancyproblem',
#  'user user wtf pretti sure ca result precinct count big win hillari delusion',
#  'one love one love reason need love paulo coelho love',
#  'yeah haaaappppyyyyyy',
#  'user man bad supercut worst msnbc trumptrain trump wdshow maga fakenew htt',
#  'lawofattract heal altwaystoh healthi',
#  'place',
#  'user ericfriday compar polit career humanlif depict user vote democrat saniti user',
#  'model love u take u time ur',
#  'congrat well done user ricohopen',
#  'lawsuit alleg versac store',
#  'happi take risk happi risk chang life itg wisdom',
#  'hispan amp feel like stomp listen retweet boricua',
#  'user wish time spend w gf damn job keep get way fml time',
#  'someon sta tomorrow',
#  'visit gorilla simul need adapt environ need tear citi materi',
#  'cowork alreadi book flight hotel upcom trip ric',
#  'good user',
#  'first pic took look bomb asf think take idigittho',
#  'specul sentiment index blog silver gold forex',
#  'en rout alton tower altontow sun sunni',
#  'patienc caer victim crisi actor blog silver gold forex',
#  'udta punjab film circul faster hostel drug punjab',
#  'happi babi nephew laugh',
#  'user even weak abl fight zionist technolog etc use jsil amp hatr',
#  'regrann user user put togeth',
#  'user made aviari gelato grinata shaveic foodi rayban sunglass summer cool cherri icecream',
#  'pougal consum price index mom dip previou may blog silver gold forex',
#  'urdu poetri beuti poetri poetri line poetri eid new poetri tanhai poetri follow user send',
#  'user new song summermood',
#  'minut left',
#  'user love trust wrong none friend work',
#  'music attack bull chase leav lot despit fact strong sourc fo',
#  'juststandup free justshar tsmilewithouty stand user',
#  'user friskyfriday sexi peopl hotwif milf sexylatina bbg rwsw',
#  'warwickfilmshow raw tune user',
#  'user brilliant conc band make audienc happi user music summer',
#  'use power mind heal bodi altwaystoh healthi',
#  'love new rod',
#  'bird flew thank european cooper brexit would sad loss gb amp finland user',
#  'happi bihday babygirl lilli year alreadi whoop whoop bihday girl',
#  'gettin keep go thankyoujesuschrist music teacher',
#  'lincoln amp avanleigh spend fathersday wkend user beach grammaw littl beachbum grandkid famili',
#  'user town whiteland fight nativ american school mascot notyourmascot whiteprivileg via user',
#  'user racialprejudic real exist across countri sinc begin time amp need priori',
#  'user cool guess probabl show phone',
#  'fresh haircut selfi',
#  'best accident photo like like follow follow follow blackandwhit instalik bu',
#  'mood goe sad time miss someon',
#  'goodnight click ramadan kareem sehri',
#  'user user need make one tho',
#  'user news repo tonight instead day trump racist campaign maga obviou',
#  'user amp user ate wasabi met best peopl ever happi rd bday luke',
#  'user user user user right like presid obama go take everyon gun getsomefact',
#  'holiday plan januari week book work beachhut travel',
#  'thread outlin evolut alt right movement via russia focus one member',
#  'night mood user mymauritiu magic everi minut luxurytravel user user',
#  'user wait till impeach traitor deserv jail mani thing impeachtrump traitor',
#  'got new box glove today tri gym soon workingout',
#  'ase bull domin bull direct whatev want',
#  'via user',
#  'beat monday blue moethennessi mondayblu work win sta drink wine white',
#  'nigga would fck boy hit pussi',
#  'star gorilla simul need adapt environ need tear citi materi',
#  'user bad wish mari glassfetish',
#  'user inde cultur person celebr trump substanc',
#  'stop train make cri everi time listen lyric tru',
#  'wanna travel actual money nobodi want go nyc foreveralon',
#  'eat make koreanfood mypass',
#  'sleep capitalstb user user',
#  'user help left caus feel sick suppos get help hour ago',
#  'first today bifold fit watford custom',
#  'awesom dynamicduo miss chri positivevib great time love bridg',
#  'decid happi percept mind life flow focu goe life',
#  'good morn nice weekend day weekend likem sun likeforlik',
#  'impress user order late sunday came today engrav perfect amp cuss gift tag',
#  'user memori day deep',
#  'user happi uh friend fulfil ur wish user thnkuh sweethea ht',
#  'time sweet friend kaceepopa beauti user',
#  'neg peopl caus neg atmospher life sho satisfi surround posit happi lifego',
#  'thank thank posit',
#  'besti gorilla simul need adapt environ need tear citi materia',
#  'user look bathroom mirror say donald trump three time hair drain rise sta yell',
#  'black amp feel like stomp retweet tampa miami',
#  'amaz health benefit cucumb healthi altwaystoh',
#  'tyler perri claim revers racism critic tlc seri tyler perri claim revers critic',
#  'user allahsoil major violenc involv quest oil emirati',
#  'look forward meet babi boy hour',
#  'pivot moment life unawar damn frog made till',
#  'heard fitciti day ago pop everywher user great talk healthi citi today',
#  'turkey land owner money benefit propey profit invest torism love compani develop sea human',
#  'sex blond bj nake',
#  'check new trend funni gif kim kardashian cri',
#  'launch anim adopt today strawberri fayr',
#  'workspac matter well workplacedesign staff matter health issu staff product',
#  'best homeopath remedi anxieti altwaystoh heal peac',
#  'urg eci conven pay meet udtapunjab issu',
#  'find sad celebr huge fandom member lgbt commun havent comment shoot',
#  'gent want make take vehicl local napaautocar center',
#  'area man hate blame twitter user notic po',
#  'blue day drown sorrow icecream blue creami icecream hnt',
#  'yellow bone girl porn hardcor track',
#  'user tgif ff gamedev indiedev indiegamedev squad user user user user user',
#  'user tweet sheet keep go korea tour amp slaughter wors yulin korea kill amp tour daili',
#  'user assum muslim refuge kick women stair',
#  'wait vodka gummybear',
#  'user peopl talk gay men kill peopl kill',
#  'user wahhhh white ppl arent allow fuck rich care',
#  'product weekend hard work pay selfi girl smile hardwork',
#  'cool user feel good univers agre alway felt colleg',
#  'brother sister take note everyon quick listen slow speak slow becom jame',
#  'brilliant posit affirm',
#  'user thank kiss thank posit',
#  'serious wrong stoptheviol yr old kill vigil victim',
#  'fusionmad miss omg motiv',
#  'side guy without home',
#  'saw dean ambros money bank ladder match cash wow wow wwe stun shock',
#  'trump said understand anyth presid said trump admit stupid dumbest ever dumbasstrump',
#  'ripantonyelchin die car accid believ likecrazi',
#  'disgust realli hope know piec crap sodon',
#  'shame watch h le man tv amp annoy',
#  'user user user user ationalbedfriendsday jump',
#  'happi sunday sunday workout leed weightloss weightlosstrain theedg',
#  'lot ing throw decid take plung purchas bumbag today hol retro',
#  'good morn hope great day pic girl photo instagram',
#  'user get wors much wors shoot small scale wait much bigger attack kill thousand',
#  'happi filanfriday user hope like shanefilan myedit smile like love',
#  'sydney usa root john scott wear canadian jersey',
#  'want',
#  'bday user amp tupac rapflashback gemini hiphop og tbt legend june',
#  'user devi hippo calf photo sandiegozoo dream love hope health peac amp',
#  'belgium boatpay pay paytim londonescap wear asiafashion',
#  'lighttherapi help depress altwaystoh healthi happi',
#  'day orlando',
#  'user thank user packag anybodi need anyth design amp print recommend user',
#  'experiment track produc morn edm dnb trap tune fastcor',
#  'big warm shoulder cri father day',
#  'friday weekend work fast bca',
#  'warren zevon keep hea via user watch docu make album thewind',
#  'terribl tragedi r p christinagrimmi world scari place heabroken',
#  'damn realli made tear littl mustread',
#  'user never get busi make live forget make life thailand come home',
#  'back low cut grayhair dontcar friday yeahhh',
#  'first time take bu work new hous let see goe',
#  'user sad day racist question whether candid racist live multiraci countri',
#  'disneygatorattack happen previou disney allig attack victim messag boy famili',
#  'gino play blue guitar',
#  'yummi apbtapizaco firstanniversari apbt',
#  'back let sta twit',
#  'ghost adventur time fo macahur nichol xx',
#  'eeek week today pick furbabi',
#  'ty user user join blendedlearn convers valleymm',
#  'user work sunshin happi summerfeel love best summer work break',
#  'wow trump crowd half size berni turn hillari suppoer crowd',
#  'sweet stuff shown e year everyon look forward videogam vr',
#  'user user listen metorit reviv definit pianohand tonight sevenyearsofpodcast',
#  'mani tool function',
#  'rememb happi felic felicit aldil ditutto behappi rememb ricorda',
#  'user win facebook meatfeast competit user amp wait till next tuesday meat wine',
#  'user user user user sexless season love scene impoant see disappoint puzzl outland',
#  'bracebridg huntsvil look hous unsur happi willmisseveryon notlikeisrranyofmyfriendsanyway theirlif busi',
#  'hey user user wait get cheddar biscuit chang someth',
#  'user user agre everyon deserv use',
#  'could make almost year tennesse yeah honey stay forev west virginia know',
#  'user user user heather block user real gem hand',
#  'user user lead ignor lovetrumpsh janeelliot',
#  'wohoooo staup weekend sibu staup weekend miri come q yall mega staup sarawak end year',
#  'thank food thank posit',
#  'user unemploy ye still use twitter tri argu teen pathet tryagain',
#  'sure meickenhorst know inspir',
#  'user posit keep travel gtc mydubai dubai love smile care travel tourism abudhabi uae trip',
#  'heali osborn ohelptobuy scheme renam help bonus outrag shock',
#  'crack corn x bic pen outcast ink sketchbook sketchi sketch fear scar',
#  'week day till see babe countdown iwannagonow',
#  'yep let googl hit butt way mustend',
#  'readi e',
#  'real friday chuckaboo picoftheday loveit day enjoy tgif danc',
#  'nationalbestfriendday marri mine bff husband love joy marriag',
#  'celebr dad today fathersday menu',
#  'hello friday fit fitfam ab health model fashion blogger',
#  'model love u take u time ur',
#  'marathon gorilla simul need adapt environ need tear citi materi',
#  'wow colga u guy shoot guy headshot basketbal cou real smh doubl church smdh',
#  'fit fit better tip vegatopian user eathealthi',
#  'friyay everyon deserv via user showusthosepearlywhit',
#  'life make let make motiv',
#  'see facebookmemori remind even life pretti shit turn around amp amaz goodjob amazingboy',
#  'user bihday bro',
#  'user user user user affluent amp million like way focu one word smh',
#  'user alway run banana nut muffin',
#  'user alreadi feel anoth hit',
#  'user user user user',
#  'music ban iraivi movi',
#  'happi happi lyric',
#  'user user gracia messi alon',
#  'elli ate stalk asparagu child dream luckymom',
#  'bihday sexi girl adult hentai',
#  'found child bodi still intact hope bring closur famili',
#  'noth els get selfi lol random selfi snapchat',
#  'got haircut good day wear oakley selfi smile bore hair',
#  'user sad may rest peac',
#  'model love u take u time ur',
#  'user user user see later',
#  'tyler kid annoy grew love engag inlov',
#  'user poor vote gop gun religion ignor aboion fear',
#  'epic pay bihday user thankyou amaz fun pay',
#  'user got real user user fireston user firsttimesponsor',
#  'happi day night',
#  'imagem via hea amaz food look smile',
#  'user hindusena celebr messiha bihday delhi messiha talk kick indian america',
#  'canadian inconceiv easili buy assault rifl us terribl tragedi gunlaw orlandoshoot',
#  'user greatest teacher uncondit love teach room amp board pet',
#  'user atherapi musictherapi heal life altwaystoh healthi heal',
#  'feel music imback black guitar guy feel play till die',
#  'congratul amaz parent year togeth anniversari mom dad',
#  'user user user way hide behind broad statement folk know wrong gener',
#  'last two day norway see iaraheid move movingabroad backtoitali',
#  'know tweet harsh time give credit due say peopl afraid musicro',
#  'user head london day user user academi addit danburi essex x',
#  'happi father day fathersday bestdaddi sunnyday smile flawless beach ocean',
#  'boy download dl daddysonday',
#  'great day w seed scholar user top come home amaz neighbor surpris us kind gestur bless',
#  'user watch us open dad miss pop fathersday love usopen first year without',
#  'sta rust offici seri half way go sta singl player game seri hype',
#  'user user user nobdi want kiss lie conaist homophob islamaphob russianhack nom',
#  'launch go well mani reader avail take l k might realli appeal',
#  'weather sydney next week bad bad sydney',
#  'yey new motorbik way issu park anymor stuff traffic warden yamaha',
#  'cheer argentina regard malvina messi deserv',
#  'rainbow parad vienna best open inclus divers livabl lgbtcommun publicspac',
#  'user provo get hair cut sinc mom graduat nostalgia',
#  'updat social analyt convers instadaili game',
#  'user term leg room one less space think right nothappi',
#  'smile dog dogsarejoy',
#  'saw hatchl sho birdsmovi reason view film earlier shall',
#  'famili caus problem relationship pick friend reason horrif life',
#  'control love amp hip hop gangster rap music',
#  'believ brother love island notif phone loveisland',
#  'check enjoy ukulel royalti free music victoryaudio audiojungl ukulel music',
#  'babi kidkus driveway safeti net feet bouncingbabi',
#  'user let get lost find steadi',
#  'final see pictur orlando shooter realiz went high school togeth prayfororlando',
#  'know one squirrel mate nowher found mother natur bitch night',
#  'touch gestur watcho wwdc',
#  'pleas like amp share agre dna dnaquot quot quoteoftheday love proverb lifestyl',
#  'thank show even watch user user catchup joke sky ruin',
#  'treat beaut sunflow make saturdayvib',
#  'user allahsoil temptat blame everyth scapegoat strong resist',
#  'mother beep great day instagram posit fun awesom',
#  'user donald unfavor rate',
#  'user user lot compani tara stand principl mani sell user',
#  'enjoy holiday hello tokyo taiwan tokyo holiday love narita',
#  'user love meet new today quick learner enjoy walk dictat pa bodi transit',
#  'newstar bull domin bull direct whatev want',
#  'wait saturday night go see user theconjur regalcinema truestori',
#  'user staff member tell fib transfer number nano sim instead gave new number complaint missold',
#  'user father day thalaivaa vijay bdayspl week',
#  'abrahamhick bring best other via user kind kind help help',
#  ...]

# %%
onehot_repr_t = [one_hot(words,voc_size)for words in corpus_t]
print(onehot_repr_t)
# Out:
# [[4385, 403, 1691, 1552, 1138, 4114, 1855, 12], [845, 2689, 1160, 1530, 2888, 3711, 1628, 3626, 823], [2925, 3243, 2130, 681, 1231, 247, 2130], [107, 4191, 4934, 2867, 2258, 4105, 4673, 2936, 96, 2563], [2149, 2176, 2646, 3331, 1925, 3911, 4100, 501, 4169, 3275, 4796], [647, 3121], [2828, 4240, 30, 887, 901, 3252, 777, 4734, 3072, 4546], [3839, 4847, 1061, 1061, 2270, 1273, 2002], [845, 845, 845, 4158, 2185, 4771, 3533, 3508, 1113, 1971], [325, 3890, 262, 3793, 1673, 1076], [1134, 2444, 2960, 3814, 2896, 1294, 3281, 526, 935, 3671], [104, 1438, 1119, 1652, 2891, 2254, 1052], [4190, 3243, 2233, 1708], [638, 3890, 638, 4082, 227, 283, 3710, 4495, 4812], [3641, 88, 2566, 4064, 728, 835, 2250], [2290, 2290, 2290, 4738, 1648, 4424, 2940, 1305, 4156, 4777], [845, 3768, 845, 1766, 1814, 4526, 312, 4838, 2921, 845, 845, 845, 845], [3382, 3275, 3382, 1824, 3382, 48, 2088, 1100, 3236, 1245], [4427, 1645, 1336, 4672, 2858, 1516], [2551, 60, 4362, 4050, 2123, 1312, 631, 3741, 3146, 1804, 3688, 1808, 1906, 364], [4630, 2922, 4969, 3288, 3391, 4370, 1807, 147], [845, 845, 845, 3617, 673, 252, 673, 2229, 4082, 4971], [3227, 3321, 83, 3321, 4101, 4262], [4158, 4766, 4082], [3694, 2756, 3389, 3389, 4413, 1405, 4686, 2288, 4048], [2551, 1000, 1998, 1492, 681, 3117, 4427, 4774, 1676, 3853, 1645], [4584, 550, 344, 2944, 2393, 3265], [1807, 4184, 2810, 1903, 3275, 3735, 617, 4759, 4764, 4103], [3535, 193, 1292, 231, 2888, 247, 193], [845, 845, 293, 105, 293, 179, 3275, 2149, 360, 1336, 3382, 1113, 2347], [4158, 1817, 224, 2921], [845, 1628, 845, 4678, 200, 2365, 546, 1002, 2872, 3814, 4183, 154], [828, 954, 4954, 1951, 2365, 777, 415, 2633, 4987, 4146, 4958], [2626, 4722, 4569, 2362, 463, 3477, 4722, 3202, 2992], [4620, 4412, 4224, 2064, 273, 2081, 2208], [2536, 4551, 1015], [3890, 4289, 1818, 1585, 3310, 3116, 1273, 4418, 3114], [845, 4624, 2689, 364, 361, 364, 4101, 3226, 124, 230, 4014, 2921], [2176, 995, 2536, 1208, 4039, 4119, 3265, 475], [788], [3608, 2718, 3711, 1253, 2229, 2769, 2828, 2238, 2718], [882, 3890, 777, 2268, 1231, 247, 2130, 1124, 4280, 3275], [845, 845, 1808, 3568, 768, 806, 410, 3820, 4577, 22, 318], [1679, 2348, 2176, 3608, 3233, 1683, 1183, 88, 657, 610, 3382, 2919, 2921], [2046, 4097, 3333, 1862, 4933, 4362, 121, 359, 845], [1100, 4169, 2969, 3974, 3231, 2818, 1024, 4289, 4913, 1183, 845, 193, 941], [3275, 4381, 3391], [845, 3182, 3760, 4456, 1492, 3212], [1438, 2896, 4383, 2896, 1807, 4153, 2913, 3401, 1304, 1124], [3890, 2130, 83, 3170, 247], [227, 3760, 4418, 638, 4933, 3825, 2478, 2640, 4280], [845, 2515, 1349, 429], [845, 4083, 2922, 3109, 654, 862, 3740, 2840, 2772, 4371], [1372, 454, 1087, 4747, 454, 807, 89, 2718, 4328, 3671], [1980, 845, 550, 812, 4316, 989, 2343, 1230], [845, 845, 845, 845, 3951, 2978, 3235, 3169, 3391, 4895, 845, 2431], [1273, 2718, 1273, 3470], [1000, 2134, 2179, 1100, 4832, 3929, 2578, 4704, 1100, 4418, 1428, 2869, 3906], [1536, 1100, 4092], [1370, 4470, 2935], [4289, 2935, 1366, 948, 3247, 517, 297, 3771, 1037], [4435, 3275, 2520, 1615, 2520, 4289, 1395], [2616, 783, 4491, 1383, 1231, 247], [638, 3875, 2888, 3875, 3182, 4456, 2565], [611, 307, 2064, 456, 1346, 4259, 2505, 1383, 2179, 4257, 550, 1733, 2059, 550, 590, 3401], [300, 2412, 1411, 293, 2185, 1892, 3382, 4343, 2475, 4070, 3382, 1204, 356, 4207, 3328, 3141], [4289, 4079, 3711, 3244, 1132, 3244, 308], [1565, 3066, 1786, 1611, 2483, 4463, 1432, 1273, 683], [1135, 2607, 3229, 4532, 3391, 448, 448, 845, 4680, 4246, 845], [2437, 300, 3533, 4617, 1002, 174, 2343, 4289, 1355, 142, 422, 3254, 2189, 2090], [840, 360, 783, 1698, 783, 1698, 389, 845, 4317, 1651, 4860], [891, 4039, 845, 3608, 845, 3180, 2366, 322], [1432, 4600, 3182, 3982, 638, 3182, 3820, 3114], [2847, 3153, 1855, 3331, 3558, 4544, 4522, 4308], [845, 935, 3533, 2867, 3382, 3920, 933, 690, 784, 4832, 4155, 3643, 4718], [845, 1525, 4183, 845, 3880, 834, 3093, 2319, 591], [293, 3859, 3243, 2896, 4551, 4495, 104, 2854, 1685, 4979, 3298], [546, 1253, 3736, 2020, 2479, 2887, 3661, 238 ...

# %%
sent_length=20
embedded_docs_t = pad_sequences(onehot_repr_t,padding='pre',maxlen=sent_length)
print(embedded_docs_t)
# Out:
# [[   0    0    0 ... 4114 1855   12]
#  [   0    0    0 ... 1628 3626  823]
#  [   0    0    0 ... 1231  247 2130]
#  ...
#  [   0    0 3735 ... 4534 2913 2183]
#  [   0    0    0 ... 2329 4183 2673]
#  [   0    0    0 ... 4736 1072 1413]]

# %%
x_test_t = np.array(embedded_docs_t)

# %%
test = model.predict(x_test_t)
# Out:
# 538/538 [==============================] - 2s 3ms/step

# %%
test=np.where(test>=0.5,1,0)

# %%
test.shape
# Out:
# (17197, 1)

# %%
df1.shape
# Out:
# (17197, 2)

# %%
df1['label_pred'] = test

# %%
df1.to_csv("submission.csv")
